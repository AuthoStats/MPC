# %%
from controllers import *
#open(os.path.join('Aspen Stuff', 'stop.txt'), 'w').close()

# %%
wipeFolder('Aspen Stuff')
# %matplotlib widget
#p1,p2,p3,p4,p5,p6,p7,p8,p9,p10 = [200,200,400,1000,2.5 ,250,250  ,200,1000  ,0.5]
#p1,p2,p3,p4,p5,p6,p7,p8,p9,p10 = 1e4*np.array([0.6357972255156994,96707.55554749382,1.0790583979938957,60.86066360843278,0.0002578547214190546 ,17.5124842176659,101949.56051420174  ,104.37657105590257,3.128718017349537  ,0.000010846300887665446])
# p1,p2,p3,p4,p5,p6,p7,p8,p9,p10 = 1e4*np.array([0.0022651943949355755, 99862.1425902443,0.0037207980131110587,0.23169361065482735, 99997.5847989014,0.12560566345806118,58.34210398144645,2.3147505112012268,5.8635314442677045,98975.1811344455])
# p1,p2,p3,p4,p5,p6,p7,p8,p9,p10 = 1e6*np.array([0.0009702344234737915,1.1216300873784233,0.0015283028135708204,1.1220321466763308,0.0000003056064046823101,0.0012133090221050846,1.1216300873784233,0.0019023081463311001,1.1216838484014913,0.00000022497017009016127])

# P matrix values: P is a Positive definite 10x10 real matrix 
P1 = 200
P2= 250
P3= 2500
P4=10
P5=0.25
P6=1000
P7=1000
P8=500
P9=1
P10=0.5

# k_1,k_2,k_3 = 1500898.8475089157, 51911.41903311291, 4.166999999999997
# #E_1,E_2,E_3 = 7.94305039e+04,7.96897538e+04,1.24494237e+05
# Cp1,Cp2 = 1.8097737040262707, 2.6356562630366525
# Out:
# File does not exist: c:\Users\arthu\JupyterNotebook\Code\MPC\Aspen\Aspen Stuff\greenLightAspen
# File does not exist: c:\Users\arthu\JupyterNotebook\Code\MPC\Aspen\Aspen Stuff\greenLightPython
# File does not exist: c:\Users\arthu\JupyterNotebook\Code\MPC\Aspen\Aspen Stuff\u.txt
# File does not exist: c:\Users\arthu\JupyterNotebook\Code\MPC\Aspen\Aspen Stuff\dynamicValues.txt
# File deletion process completed.

# %%
from controllers import *
# %matplotlib widget
# controlStepSize = 100
# hcMPC = 0.3
#Process time is 6hr
#Sampling time is 30 seconds
#Integration timestep is 0.3s


netSteps = netPIControlTimeSteps
targetTemps = np.array([50.0,100.0])
Kc=np.array([500.0, 1500.0])
Ki=np.array([0.1, 0.1])

# Initial Values
initialValues = np.loadtxt(os.path.join('Aspen Stuff', 'initialValues.txt'), delimiter=",")
C_B1_i   = initialValues[0,0] - C_B1s    # kmol/m3
C_DEB1_i = initialValues[0,1] - C_DEB1s  # kmol/m3
C_E1_i   = initialValues[0,2] - C_E1s    # kmol/m3
C_EB1_i  = initialValues[0,3] - C_EB1s   # kmol/m3
T_1_i    = initialValues[0,4] - T_1s     # K
C_B2_i   = initialValues[1,0] - C_B2s    # kmol/m3
C_DEB2_i = initialValues[1,1] - C_DEB2s  # kmol/m3
C_E2_i   = initialValues[1,2] - C_E2s    # kmol/m3
C_EB2_i  = initialValues[1,3] - C_EB2s   # kmol/m3
T_2_i    = initialValues[1,4] - T_2s     # K

# Initialize the state, control, and error Records
stateRecord = np.zeros((2,5,netSteps+1))
stateRecord[0,0,0] = C_B1_i 
stateRecord[0,1,0] = C_DEB1_i
stateRecord[0,2,0] = C_E1_i
stateRecord[0,3,0] = C_EB1_i
stateRecord[0,4,0] = T_1_i
stateRecord[1,0,0] = C_B2_i
stateRecord[1,1,0] = C_DEB2_i
stateRecord[1,2,0] = C_E2_i
stateRecord[1,3,0] = C_EB2_i
stateRecord[1,4,0] = T_2_i

#Steady State Values of state variables
Q1d     = Q_(-306.00127008393844 ,'kJ/s').magnitude                - Q1s
Q2d     = Q_(-519.6721950335846 ,'kJ/s').magnitude              - Q2s
C_B1d   = Q_(5.7227369200741904 ,'kmol/m^3').magnitude      - C_B1s    # kmol/m3
C_DEB1d = Q_(3.7847819651713003e-05 ,'kmol/m^3').magnitude - C_DEB1s  # kmol/m3
C_E1d   = Q_(9.4830667871228003e-01 ,'kmol/m^3').magnitude      - C_E1s    # kmol/m3
C_EB1d  = Q_(9.6137458085552596e-01 ,'kmol/m^3').magnitude     - C_EB1s   # kmol/m3
T_1d    = Q_(3.5021535778966199e+02 ,'K').magnitude             - T_1s     # K
C_B2d   = Q_(4.2242089099114501 ,'kmol/m^3').magnitude      - C_B2s    # kmol/m3
C_DEB2d = Q_(2.1677362152708099e-04 ,'kmol/m^3').magnitude - C_DEB2s  # kmol/m3
C_E2d   = Q_(1.6699014297496406e-01 ,'kmol/m^3').magnitude       - C_E2s    # kmol/m3
C_EB2d  = Q_(1.6460876946348100 ,'kmol/m^3').magnitude      - C_EB2s   # kmol/m3
T_2d    = Q_(4.0050873892022503e+02 ,'K').magnitude             - T_2s     # K

controlRecord = np.zeros((2,netSteps))
costRecord = np.zeros((netSteps))
errorRecord = [[encrypt(0.,'Q')] for _ in controlRecord]

###########Q Matrices for Cost Function##############
# Qx=np.diag(np.tile([2e3, 1], int(NUM_OUTPUTS/2)))
# Qu=np.diag(np.tile([8e-13, 0.001], int(NUM_OUTPUTS/2)))
loopsPerHour = int(((1.0*60*60)/hcPI)/controlStepSize)
A1 = np.repeat(10*np.ones(6),loopsPerHour)
A2 = np.repeat(10*np.ones(6),loopsPerHour)
A3 = np.repeat(1e-8*np.ones(6),loopsPerHour)
A4 = 0.08
A5 = 0.1
# A1 = np.repeat(10*np.array([1, 0.9, 1.1, 0.8, 1.2, 0.7]),loopsPerHour)
# A2 = np.repeat(1e-8*np.array([1, 0.8 , 1.2, 0.6 , 1.4,0.5]),loopsPerHour)

# Storing the steady state values in 2 arrays
x_ss = np.array([[ C_B1s,C_DEB1s, C_E1s,C_EB1s,  T_1s], [ C_B2s,C_DEB2s,C_E2s, C_EB2s,  T_2s]])
print(f"The steady state values are {x_ss}")

# Transfer the initial values into realtime array, wont store the data permanently, created record lists for that.
currentState = np.array([[ C_B1_i,C_DEB1_i,C_E1_i, C_EB1_i,  T_1_i], [ C_B2_i, C_DEB2_i,C_E2_i, C_EB2_i, T_2_i]])
print(f"The initial values are {currentState}")
# Out:
# The steady state values are [[6.95758474e+00 3.10286075e-08 1.95760263e+00 4.23901308e-02
#   3.00000000e+02]
#  [6.43501782e+00 2.81861916e-08 1.96109384e+00 3.87321918e-02
#   3.00000000e+02]]
# The initial values are [[ 4.44089210e-15 -2.64697796e-23  1.99840144e-15  1.38777878e-17
#    2.84217094e-13]
#  [ 2.66453526e-15 -1.98523347e-23 -3.99680289e-15  4.16333634e-17
#    1.70530257e-13]]

# %%
###################### MPC Cost Weight Matrix #####################
q1 =5
q2 =5
q3=650
q4=5
q5=2.5
q6=25
q7=25
q8=100
q9=2
q10=6

r1 = 5*1e-6
r2 = 1.25*1e-5
#Transfer the initial values into realtime array, wont store the data permanently, created record lists for that. 
#realtime_data1 = np.array([CE1_i, CB1_i, CEB1_i, CDEB1_i, T1_i])
#realtime_data2 = np.array([CE2_i, CB2_i, CEB2_i, CDEB2_i, T2_i])
Cp = Cp1
Coeff1 = F1/V1
Coeff2 = F1/V2
Coeff3 = F2_new/V2
@njit
def model_makestep(x,u, steps=100, hc=1e-4):
    C_B1,C_DEB1,C_E1,C_EB1,T_1,C_B2,C_DEB2,C_E2,C_EB2,T_2 = x
    Q1,Q2 = u
    for _ in range(steps):
        r1_1  = k_1*math.exp(-E_1/R/(T_1+T_1s))*((C_B1+C_B1s)*(C_E1+C_E1s))
        r1s_1 = k_1*math.exp(-E_1/R/T_1s)*(C_B1s*C_E1s)
        r2_1  = k_2*math.exp(-E_2/R/(T_1+T_1s))*((C_EB1+C_EB1s)*(C_E1+C_E1s))
        r2s_1 = k_2*math.exp(-E_2/R/T_1s)*(C_EB1s*C_E1s)
        r3_1  = k_3*math.exp(-E_3/R/(T_1+T_1s))*((C_B1+C_B1s)*(C_DEB1+C_DEB1s))
        r3s_1 = k_3*math.exp(-E_3/R/T_1s)*(C_B1s*C_DEB1s) 
        r1_2  = k_1*math.exp(-E_1/R/(T_2+T_2s))*((C_B2+C_B2s)*(C_E2+C_E2s))
        r1s_2 = k_1*math.exp(-E_1/R/T_2s)*(C_B2s*C_E2s)
        r2_2  = k_2*math.exp(-E_2/R/(T_2+T_2s))*((C_EB2+C_EB2s)*(C_E2+C_E2s))
        r2s_2 = k_2*math.exp(-E_2/R/T_2s)*(C_EB2s*C_E2s)
        r3_2  = k_3*math.exp(-E_3/R/(T_2+T_2s))*((C_B2+C_B2s)*(C_DEB2+C_DEB2s))
        r3s_2 = k_3*math.exp(-E_3/R/T_2s)*(C_B2s*C_DEB2s)

        C_B1   = max(-C_B1s,C_B1+hc*(Coeff1*(-C_B1)                            - r1_1 + r1s_1  - r3_1 + r3s_1))
        C_B2   = max(-C_B2s,C_B2+hc*(Coeff2*(C_B1-C_B2)     + Coeff3*(-C_B2)   - r1_2 + r1s_2  - r3_2 + r3s_2))
        C_DEB1 = max(-C_DEB1s,C_DEB1+hc*(Coeff1*(-C_DEB1)                          + r2_1 - r2s_1 - r3_1 + r3s_1))
        C_DEB2 = max(-C_DEB2s,C_DEB2+hc*(Coeff2*(C_DEB1-C_DEB2) + Coeff3*(-C_DEB2) + r2_2 - r2s_2 - r3_2 + r3s_2))
        C_E1   = max(-C_E1s,C_E1+hc*(Coeff1*(-C_E1)                            - r1_1 + r1s_1  - r2_1 + r2s_1))
        C_E2   = max(-C_E2s,C_E2+hc*(Coeff2*(C_E1-C_E2)     + Coeff3*(-C_E2)   - r1_2 + r1s_2  - r2_2 + r2s_2))
        C_EB1  = max(-C_EB1s,C_EB1+hc*(Coeff1*(-C_EB1)                           + r1_1 - r1s_1  - r2_1 + r2s_1 + 2*(r3_1-r3s_1)))
        C_EB2  = max(-C_EB2s,C_EB2+hc*(Coeff2*(C_EB1-C_EB2)   + Coeff3*(-C_EB2)  + r1_2 - r1s_2  - r2_2 + r2s_2 + 2*(r3_2-r3s_2)))
        T_1    = max(-T_1s,T_1+hc*(Coeff1*(-T_1)                    - H_1*(r1_1-r1s_1)/(rhoe_L1*Cp1) - H_2*(r2_1-r2s_1)/(rhoe_L1*Cp1)- H_3*(r3_1-r3s_1)/(rhoe_L1*Cp1) +Q1/(rhoe_L1 * Cp1 * V1)))
        T_2    = max(-T_2s,T_2+hc*(Coeff2*(T_1-T_2) + Coeff3*(-T_2) - H_1*(r1_2-r1s_2)/(rhoe_L2*Cp2) - H_2*(r2_2-r2s_2)/(rhoe_L2*Cp2)- H_3*(r3_2-r3s_2)/(rhoe_L2*Cp2) +Q2/(rhoe_L2 * Cp2 * V2)))
    return np.array([C_B1,C_DEB1,C_E1,C_EB1,T_1,C_B2,C_DEB2,C_E2,C_EB2,T_2])
def eval_f(u):
    offset=0
    x = stateRecord[:,:,main_iteration].reshape(-1)
    ### check how to write the inputs 
    for controlIteration in range(controlTimeStepsPerMPC):
        Q1    = u.item(NUM_U*controlIteration + 0)  # Heat input for reactor 1
        Q2    = u.item(NUM_U*controlIteration + 1)  # Heat input for reactor 2
        
        # Update states for both reactors
        x = model_makestep(x, [Q1,Q2], controlStepSize, hcMPC)
        x1,x2,x3,x4,x5,x6,x7,x8,x9,x10 = x
        
        offset += q1*((C_B1d-x1)**2.0) + q2*((C_DEB1d-x2)**2.0) + q3*((C_E1d-x3)**2.0) + q4*((C_EB1d-x4)**2.0) + q5*((T_1d-x5)**2.0) \
        +q6*((C_B2d-x6)**2.0) + q7*((C_DEB2d-x7)**2.0) + q8*((C_E2d-x8)**2.0) + q9*((C_EB2d-x9)**2.0) + q10*((T_2d-x10)**2.0)
        
        offset= offset +  (Q1d - u[2*controlIteration+0]) **2*r1  + (Q2d - u[2*controlIteration+1]) **2 *r2
        #offset_record.append(offset/10)
        
    return offset*delta
def calcCost(x,u,index):
    val1 =-A1[:index+1]*(x[1,3,1:index+2]+ C_EB2s)
    val2 =-A2[:index+1]*(x[0,3,1:index+2]+ C_EB1s)
    val3 = A3[:index+1]*((u[0,:index+1]+Q1s)**2 + (u[1,:index+1]+Q2s)**2)
    val4 = A4*np.maximum(0,x[0,-1,1:index+2]-(350-T_1s))
    val5 = A5*np.maximum(0,x[1,-1,1:index+2]-(400-T_2s))
    # print(val1)
    # print(val2)
    # print(val3)
    # print(val4)
    # print(val5)
    return sum(val1+val2+val3+val4+val5)
#Computing the gradient of f(x) which represents the cost function and hence its the derivative of the cost function.
def eval_grad_f(x):
    assert len(x) == int(NUM_MPC_INPUTS)
    step = 1.0e-3 # we just have a small step
    objp=objm=0
    grad_f = [0]*NUM_MPC_INPUTS
    xpstep = [0]*NUM_MPC_INPUTS
    xmstep = [0]*NUM_MPC_INPUTS
    for i_mpc_input in range(NUM_MPC_INPUTS):
        xpstep=x.copy()
        xmstep=x.copy()
        # for each variables, we need to evaluate the derivative of the function with respect to that variable, This is why we have the for loop
        xpstep[i_mpc_input]  = xpstep[i_mpc_input]+step 
        xmstep[i_mpc_input] = xmstep[i_mpc_input]-step
        # Evaluate the objective function at xpstep and xmstep
        objp=eval_f(xpstep) # This function returns the value of the objective function evaluated with the variable x[i] is perturebed +step
        objm=eval_f(xmstep) # This function returns the value of the objective function evaluated with the variable x[i] is perturebed -step
        #print ("obj ", objp, "   objm   ", objm)
        grad_f[i_mpc_input] = (objp - objm) / (2 * step) # This evaluates the gradient of the objetive function with repect to the optimization variable x[i]
    #print("Gradient: ", grad_f)
    return np.array(grad_f)



def eval_g(u):  # V condition, Vdot condition, the Energy constraint
    g = np.array([-1.0] * (controlTimeStepsPerMPC))  # Default to <0 i.e invalid
    x = stateRecord[:,:,main_iteration].reshape(-1)
    xss = x_ss.reshape(-1)
    T_1 = x.item(4)
    T_1s = xss.item(4)
    T_2 = x.item(9)
    T_2s = xss.item(9)
    deviationLimit = 0.5
    
    bias =  0
    
    
    # if np.isnan(u).any():
    #     g[:] = -1
    #     return g
    #print(u)
    if (abs(T_1/T_1s)>deviationLimit or abs(T_2/T_2s)>deviationLimit):#Check if any term is 15% off the steady state value, i.e, the system is not in the economic region
        Q1 = u.item(0)
        Q2 = u.item(1)

        LfV = 0.0
        Lg1V = (2 * P5  * T_1 ) /(rhoe_L1 * Cp1 * V1)
        Lg2V = (2 * P10 * T_2 ) /(rhoe_L2 * Cp2 * V2)
        dV_op2 = LfV + Lg1V * Q1 + Lg2V * Q2  # (EMPC)Vdot = LfV(x)+LgV(x)*u
        #print(f"dV_op2 = {dV_op2}")
        u11 = Kc.item(0) * (0.0 - T_1)
        u22 = Kc.item(1) * (0.0 - T_2)
        dV_Pu2 = LfV + Lg1V * u11 + Lg2V * u22  # (PI)Vdot = LfV(x)+LgV(x)*u
        #print(f"dV_Pu2 = {dV_Pu2}")
        g[:] = min(0.0, dV_Pu2 - bias) - dV_op2 # Ensure we perform better than the Reference Controller
    else:
        for controlIteration in range(controlTimeStepsPerMPC):
            #print(f"Before Step {controlIteration}: {x}")
            Q1   = u.item(NUM_U * controlIteration + 0)
            Q2   = u.item(NUM_U * controlIteration + 1)
            x = model_makestep(x,[Q1,Q2],controlStepSize,hcMPC)
            #print(f"After Step {controlIteration}: {x}")
            g[controlIteration] = 2*deviationLimit - abs(x.item(4)/x_ss.item(4)) - abs(x.item(9)/x_ss.item(9))
            # test = 2*deviationLimit - abs(x.item(4)/x_ss.item(4)) - abs(x.item(9)/x_ss.item(9)) # Ensure we stay in the economic region
            # if np.isnan(test):
            #     g[controlIteration] = -1
            # else:
            #     g[controlIteration] = test
    
    #print(x_ss.item(9))
    #print(g)
    return g  # f(x) + C >= 0
cons = [
    #{"type": "eq", "fun": equalityConstraints},
    #{"type": "ineq", "fun": eval_g, "jac": eval_jac_g},
    {"type": "ineq", "fun": eval_g},
]

u_L = []
u_U = []
lowerBounds = [-4e3,-3e4]       # Max cooling = 10 * heat needed to sustain first principles steady state.
upperBounds = [5e3-Q1s,5e3-Q2s] # Max heating = heat needed to raise 60m^3 or water by 80K in 1hr
for _ in range(controlTimeStepsPerMPC):
    u_L = u_L + lowerBounds
    u_U = u_U + upperBounds
bnds = [(u_L[_], u_U[_]) for _ in range(NUM_MPC_INPUTS)]

# %%
def writeInputs(u):
    inputFile = os.path.join('Aspen Stuff', 'u.txt')
    np.savetxt(inputFile, [u.item(0)+Q1s,u.item(1)+Q2s], fmt ='%.5f')
    open(os.path.join('Aspen Stuff', 'greenLightAspen'), 'w').close()
def waitForAspen():
    # Load data from Aspen
    file = os.path.join('Aspen Stuff', 'greenLightPython')
    print(f"Waiting for Aspen to send data...(Iteration #{main_iteration+1})",end='\r')
    while not os.path.isfile(file):
        pass
    print(f"Aspen Data found.",end='\r')
def readAspen():
    file = os.path.join('Aspen Stuff', 'greenLightPython')
    dynamicData = np.loadtxt(os.path.join('Aspen Stuff', 'dynamicValues.txt'), delimiter = ",")
    while os.path.isfile(file):
        try:
            os.remove(file)
        except PermissionError:
            pass
    return dynamicData
def writeResults(stateRecord,controlRecord,costRecord,index):
    stateNames = ['C_B_1_record', 'C_DEB_1_record', 'C_E_1_record', 'C_EB_1_record', 'T_1_record', 'C_B_2_record', 'C_DEB_2_record', 'C_E_2_record', 'C_EB_2_record', 'T_2_record']
    controlNames = ['Q_1_record', 'Q_2_record']
    for i, name in enumerate(stateNames):
        file = os.path.join('Results_PIcontrol-encrypted-0', f'{name}.txt')
        np.savetxt(file, stateRecord[i//5,i%5,:])
    for i, name in enumerate(controlNames):
        file = os.path.join('Results_PIcontrol-encrypted-0', f'{name}.txt')
        np.savetxt(file, controlRecord[i,:])
    file = os.path.join('Results_PIcontrol-encrypted-0', 'costRecord.txt')
    np.savetxt(file, costRecord[:])
    file = os.path.join('Results_PIcontrol-encrypted-0', 'finalIteration.txt')
    np.savetxt(file, [index+1],fmt='%i')

# %%
#Transfer the initial values into realtime array, wont store the data permanently, created record lists for that. 
start_time = time.time()
for main_iteration in range(netPIControlTimeSteps):
    print("\n\n\n")
    print("%%%%%%%%%%%%%%%%%%%%%%%%%%%%%")
    print("Iteration #", main_iteration + 1)
    print(f"Current State Variable Values: x = {stateRecord[:,:,main_iteration].reshape(-1)}")
    print("Current V Value: ", np.dot(stateRecord[:,:,main_iteration].reshape(-1),np.dot(np.diag([P1,P2,P3,P4,P5,P6,P7,P8,P9,P10]),stateRecord[:,:,main_iteration].reshape(-1))))
    print("Outside economic region:",np.any(abs(stateRecord[:,-1,main_iteration].reshape(-1)/x_ss[:,-1].reshape(-1))>0.5))
    print("Outside stability region:",np.any(abs(stateRecord[:,-1,main_iteration].reshape(-1)/x_ss[:,-1].reshape(-1))>1))
    print("%%%%%%%%%%%%%%%%%%%%%%%%%%%%%")

    u = solvePI(T=encrypt(stateRecord[:,-1,main_iteration],'Q',d1=0,isArray = True),
                T_setpoint=encrypt(targetTemps,'Q',d1=0,isArray = True),
                Kc=Kc,
                Ki=Ki,
                PIcontrolStepSize=PIcontrolStepSize,
                hc=hcPI,
                lowerBounds = lowerBounds,
                upperBounds = upperBounds,
                errorRecord = errorRecord,
                encrypted = True,
                precision = 0, 
                isArray = True)
    
    # Define the initial values of the Control Variables
    controlRecord[0][main_iteration] =  u.item(0)
    controlRecord[1][main_iteration] =  u.item(1)
    #writeInputs(u)
    #waitForAspen()
    #dynamicData = readAspen()
    stateRecord[:,:,main_iteration+1] = model_makestep(stateRecord[:,:,main_iteration].reshape(-1),u.reshape(-1),PIcontrolStepSize,hcPI).reshape(2,5)
    #stateRecord[:,:,main_iteration+1] = dynamicData - x_ss
    costRecord[main_iteration] = calcCost(stateRecord,controlRecord,main_iteration)
    writeResults(stateRecord,controlRecord,costRecord,main_iteration)

end_time = time.time()

total_runtime = end_time - start_time
print("Total time required to execute the code = %f seconds " % total_runtime)
# Out:
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# Iteration # 1
# Current State Variable Values: x = [ 4.44089210e-15 -2.64697796e-23  1.99840144e-15  1.38777878e-17
#   2.84217094e-13  2.66453526e-15 -1.98523347e-23 -3.99680289e-15
#   4.16333634e-17  1.70530257e-13]
# Current V Value:  6.375041720811883e-26
# Outside economic region: False
# Outside stability region: False
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# Iteration # 2
# Current State Variable Values: x = [-1.56490558e-07  1.70083656e-13 -1.56490731e-07  1.56490392e-07
#   1.64011392e-01 -1.52581973e-07  1.63838274e-13 -1.52582144e-07
#   1.52581812e-07  1.72548477e-01]
# Current V Value:  0.021611422801002388
# Outside economic region: False
# Outside stability region: False
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#
#
#
#
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# Iteration # 3
# Current State Variable Values: x = [-6.31980120e-07  6.87574800e-13 -6.31980810e-07  6.31979436e-07
#   3.27945942e-01 -6.16322453e-07  6.62497417e-13 -6.16323122e-07
#   6.16321793e-07  3.44999236e-01]
# Current V Value:  0.08639937316287048
# Outside economic region: False
# Outside stability region: False
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#
#
#
#
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# Iteration # 4
# Current State Variable Values: x = [-1.43081546e-06  1.55827950e-12 -1.43081702e-06  1.43081391e-06
#   4.91804002e-01 -1.39565441e-06  1.50183252e-12 -1.39565592e-06
#   1.39565291e-06  5.17352682e-01]
# Current V Value:  0.19429470109347002
# Outside economic region: False
# Outside stability region: False
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#
#
#
#
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# Iteration # 5
# Current State Variable Values: x = [-2.55739813e-06  2.78810036e-12 -2.55740092e-06  2.55739535e-06
#   6.55585927e-01 -2.49506873e-06  2.68779973e-12 -2.49507142e-06
#   2.49506604e-06  6.89609226e-01]
# Current V Value:  0.3452286963371025
# Outside economic region: False
# Outside stability region: False
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#
#
#
#
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# Iteration # 6
# Current State Variable Values: x = [-4.01618507e-06  4.38303811e-12 -4.01618946e-06  4.01618070e-06
#   8.19292079e-01 -3.91911486e-06  4.22645803e-12 -3.91911909e-06
#   3.91911064e-06  8.61769283e-01]
# Current V Value:  0.5391330929855314
# Outside economic region: False
# Outside stability region: False
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#
#
#
#
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# Iteration # 7
# Current State Variable Values: x = [-5.81168922e-06  6.34919333e-12 -5.81169557e-06  5.81168288e-06
#   9.82922819e-01 -5.67240151e-06  6.12397103e-12 -5.67240764e-06
#   5.67239539e-06  1.03383327e+00]
# Current V Value:  0.7759400741572031
# Outside economic region: False
# Outside stability region: False
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#
#
#
#
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# Iteration # 8
# Current State Variable Values: x = [-7.94848014e-06  8.69276812e-12 -7.94848884e-06  7.94847145e-06
#   1.14647852e+00 -7.75959729e-06  8.38660881e-12 -7.75960568e-06
#   7.75958891e-06  1.20580162e+00]
# Current V Value:  1.055582276745601
# Outside economic region: False
# Outside stability region: False
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#
#
#
#
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# Iteration # 9
# Current State Variable Values: x = [-1.04311847e-05  1.14200679e-11 -1.04311961e-05  1.04311733e-05
#   1.30995954e+00 -1.01854314e-05  1.10207498e-11 -1.01854425e-05
#   1.01854204e-05  1.37767474e+00]
# Current V Value:  1.3779927962376743
# Outside economic region: False
# Outside stability region: False
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#
#
#
#
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# Iteration # 10
# Current State Variable Values: x = [-1.32644876e-05  1.45375030e-11 -1.32645021e-05  1.32644730e-05
#   1.47336627e+00 -1.29546945e-05  1.40328828e-11 -1.29547085e-05
#   1.29546805e-05  1.54945308e+00]
# Current V Value:  1.74310519160331
# Outside economic region: False
# Outside stability region: False
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#
#
#
#
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# Iteration # 11
# Current State Variable Values: x = [-1.64531321e-05  1.80515908e-11 -1.64531501e-05  1.64531140e-05
#   1.63669908e+00 -1.60722390e-05  1.74296087e-11 -1.60722564e-05
#   1.60722215e-05  1.72113707e+00]
# Current V Value:  2.150853490256831
# Outside economic region: False
# Outside stability region: False
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#
#
#
#
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# Iteration # 12
# Current State Variable Values: x = [-2.00019207e-05  2.19689571e-11 -2.00019427e-05  2.00018988e-05
#   1.79995835e+00 -1.95429801e-05  2.12176426e-11 -1.95430014e-05
#   1.95429589e-05  1.89272714e+00]
# Current V Value:  2.601172193091518
# Outside economic region: False
# Outside stability region: False
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#
#
#
#
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# Iteration # 13
# Current State Variable Values: x = [-2.39157159e-05  2.62963385e-11 -2.39157421e-05  2.39156896e-05
#   1.96314447e+00 -2.33718967e-05  2.54038159e-11 -2.33719221e-05
#   2.33718713e-05  2.06422375e+00]
# Current V Value:  3.093996279588151
# Outside economic region: False
# Outside stability region: False
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#
#
#
#
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# Iteration # 14
# Current State Variable Values: x = [-2.81994404e-05  3.10405839e-11 -2.81994714e-05  2.81994093e-05
#   2.12625784e+00 -2.75640314e-05  2.99950785e-11 -2.75640614e-05
#   2.75640014e-05  2.23562735e+00]
# Current V Value:  3.629261212998638
# Outside economic region: False
# Outside stability region: False
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#
#
#
#
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# Iteration # 15
# Current State Variable Values: x = [-3.28580784e-05  3.62086567e-11 -3.28581146e-05  3.28580422e-05
#   2.28929884e+00 -3.21244920e-05  3.49985003e-11 -3.21245270e-05
#   3.21244570e-05  2.40693838e+00]
# Current V Value:  4.20690294560574
# Outside economic region: False
# Outside stability region: False
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#
#
#
#
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# Iteration # 16
# Current State Variable Values: x = [-3.78966758e-05  4.18076366e-11 -3.78967176e-05  3.78966340e-05
#   2.45226788e+00 -3.70584518e-05  4.04212743e-11 -3.70584922e-05
#   3.70584114e-05  2.57815730e+00]
# Current V Value:  4.826857924060003
# Outside economic region: False
# Outside stability region: False
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#
#
#
#
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# Iteration # 17
# Current State Variable Values: x = [-4.33203414e-05  4.78447220e-11 -4.33203892e-05  4.33202935e-05
#   2.61516536e+00 -4.23711505e-05  4.62707178e-11 -4.23711968e-05
#   4.23711043e-05  2.74928458e+00]
# Current V Value:  5.489063094794925
# Outside economic region: False
# Outside stability region: False
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#
#
#
#
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# Iteration # 18
# Current State Variable Values: x = [-4.91342468e-05  5.43272314e-11 -4.91343011e-05  4.91341924e-05
#   2.77799168e+00 -4.80678950e-05  5.25542756e-11 -4.80679476e-05
#   4.80678425e-05  2.92032069e+00]
# Current V Value:  6.193455909521554
# Outside economic region: False
# Outside stability region: False
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#
#
#
#
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# Iteration # 19
# Current State Variable Values: x = [-5.53436279e-05  6.12626061e-11 -5.53436892e-05  5.53435667e-05
#   2.94074726e+00 -5.41540600e-05  5.92795215e-11 -5.41541193e-05
#   5.41540007e-05  3.09126609e+00]
# Current V Value:  6.939974330803484
# Outside economic region: False
# Outside stability region: False
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#
#
#
#
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# Iteration # 20
# Current State Variable Values: x = [-6.19537853e-05  6.86584122e-11 -6.19538540e-05  6.19537167e-05
#   3.10343252e+00 -6.06350889e-05  6.64541611e-11 -6.06351553e-05
#   6.06350224e-05  3.26212126e+00]
# Current V Value:  7.7285568377136125
# Outside economic region: False
# Outside stability region: False
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#
#
#
#
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# Iteration # 21
# Current State Variable Values: x = [-6.89700849e-05  7.65223426e-11 -6.89701614e-05  6.89700084e-05
#   3.26604788e+00 -6.75164944e-05  7.40860340e-11 -6.75165685e-05
#   6.75164203e-05  3.43288669e+00]
# Current V Value:  8.559142431573612
# Outside economic region: False
# Outside stability region: False
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#
#
#
#
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# Iteration # 22
# Current State Variable Values: x = [-7.63979588e-05  8.48622195e-11 -7.63980436e-05  7.63978739e-05
#   3.42859375e+00 -7.48038596e-05  8.21831163e-11 -7.48039418e-05
#   7.48037774e-05  3.60356286e+00]
# Current V Value:  9.431670641777428
# Outside economic region: False
# Outside stability region: False
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#
#
#
#
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# Iteration # 23
# Current State Variable Values: x = [-8.42429059e-05  9.36859964e-11 -8.42429995e-05  8.42428122e-05
#   3.59107058e+00 -8.25028387e-05  9.07535231e-11 -8.25029294e-05
#   8.25027479e-05  3.77415027e+00]
# Current V Value:  10.346081531699983
# Outside economic region: False
# Outside stability region: False
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#
#
#
#
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# Iteration # 24
# Current State Variable Values: x = [-9.25104928e-05  1.03001761e-10 -9.25105958e-05  9.25103898e-05
#   3.75347878e+00 -9.06191575e-05  9.98055110e-11 -9.06192573e-05
#   9.06190577e-05  3.94464940e+00]
# Current V Value:  11.30231570469228
# Outside economic region: False
# Outside stability region: False
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#
#
#
#
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# Iteration # 25
# Current State Variable Values: x = [-1.01206354e-04  1.12817736e-10 -1.01206467e-04  1.01206242e-04
#   3.91581881e+00 -9.91586146e-05  1.09347481e-10 -9.91587239e-05
#   9.91585052e-05  4.11506076e+00]
# Current V Value:  12.300314310164175
# Outside economic region: False
# Outside stability region: False
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#
#
#
#
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# Iteration # 26
# Current State Variable Values: x = [-1.10336195e-04  1.23142284e-10 -1.10336318e-04  1.10336072e-04
#   4.07809111e+00 -1.08127082e-04  1.19387979e-10 -1.08127201e-04
#   1.08126963e-04  4.28538487e+00]
# Current V Value:  13.340019049756105
# Outside economic region: False
# Outside stability region: False
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#
#
#
#
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# Iteration # 27
# Current State Variable Values: x = [-1.19905788e-04  1.33983907e-10 -1.19905922e-04  1.19905654e-04
#   4.24029612e+00 -1.17530506e-04  1.29935704e-10 -1.17530636e-04
#   1.17530376e-04  4.45562222e+00]
# Current V Value:  14.421372183601115
# Outside economic region: False
# Outside stability region: False
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#
#
#
#
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# Iteration # 28
# Current State Variable Values: x = [-1.29920979e-04  1.45351254e-10 -1.29921125e-04  1.29920834e-04
#   4.40243430e+00 -1.27374909e-04  1.40999504e-10 -1.27375050e-04
#   1.27374768e-04  4.62577334e+00]
# Current V Value:  15.54431653667822
# Outside economic region: False
# Outside stability region: False
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#
#
#
#
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# Iteration # 29
# Current State Variable Values: x = [-1.40387684e-04  1.57253115e-10 -1.40387841e-04  1.40387527e-04
#   4.56450610e+00 -1.37666387e-04  1.52588383e-10 -1.37666540e-04
#   1.37666234e-04  4.79583875e+00]
# Current V Value:  16.708795505259072
# Outside economic region: False
# Outside stability region: False
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#
#
#
#
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# Iteration # 30
# Current State Variable Values: x = [-1.51311891e-04  1.69698433e-10 -1.51312060e-04  1.51311721e-04
#   4.72651198e+00 -1.48411115e-04  1.64711504e-10 -1.48411280e-04
#   1.48410951e-04  4.96581898e+00]
# Current V Value:  17.914753063448387
# Outside economic region: False
# Outside stability region: False
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#
#
#
#
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# Iteration # 31
# Current State Variable Values: x = [-1.62699661e-04  1.82696301e-10 -1.62699843e-04  1.62699478e-04
#   4.88845242e+00 -1.59615346e-04  1.77378187e-10 -1.59615524e-04
#   1.59615169e-04  5.13571456e+00]
# Current V Value:  19.162133769820493
# Outside economic region: False
# Outside stability region: False
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#
#
#
#
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# Iteration # 32
# Current State Variable Values: x = [-1.74557130e-04  1.96255965e-10 -1.74557326e-04  1.74556933e-04
#   5.05032788e+00 -1.71285410e-04  1.90597922e-10 -1.71285601e-04
#   1.71285219e-04  5.30552603e+00]
# Current V Value:  20.450882774152653
# Outside economic region: False
# Outside stability region: False
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#
#
#
#
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# Iteration # 33
# Current State Variable Values: x = [-1.86890508e-04  2.10386829e-10 -1.86890718e-04  1.86890297e-04
#   5.21213885e+00 -1.83427717e-04  2.04380359e-10 -1.83427922e-04
#   1.83427513e-04  5.47525393e+00]
# Current V Value:  21.780945824257067
# Outside economic region: False
# Outside stability region: False
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#
#
#
#
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# Iteration # 34
# Current State Variable Values: x = [-1.99706080e-04  2.25098458e-10 -1.99706305e-04  1.99705855e-04
#   5.37388580e+00 -1.96048758e-04  2.18735324e-10 -1.96048977e-04
#   1.96048540e-04  5.64489882e+00]
# Current V Value:  23.15226927291271
# Outside economic region: False
# Outside stability region: False
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#
#
#
#
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# Iteration # 35
# Current State Variable Values: x = [-2.13010208e-04  2.40400576e-10 -2.13010449e-04  2.13009968e-04
#   5.53556922e+00 -2.09155106e-04  2.33672813e-10 -2.09155339e-04
#   2.09154872e-04  5.81446125e+00]
# Current V Value:  24.56480008489889
# Outside economic region: False
# Outside stability region: False
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#
#
#
#
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# Iteration # 36
# Current State Variable Values: x = [-2.26809332e-04  2.56303077e-10 -2.26809589e-04  2.26809076e-04
#   5.69718960e+00 -2.22753413e-04  2.49202997e-10 -2.22753663e-04
#   2.22753164e-04  5.98394178e+00]
# Current V Value:  26.018485844131664
# Outside economic region: False
# Outside stability region: False
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#
#
#
#
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# Iteration # 37
# Current State Variable Values: x = [-2.41109969e-04  2.72816021e-10 -2.41110242e-04  2.41109696e-04
#   5.85874745e+00 -2.36850419e-04  2.65336231e-10 -2.36850684e-04
#   2.36850153e-04  6.15334098e+00]
# Current V Value:  27.513274760904814
# Outside economic region: False
# Outside stability region: False
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#
#
#
#
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# Iteration # 38
# Current State Variable Values: x = [-2.55918715e-04  2.89949639e-10 -2.55919005e-04  2.55918425e-04
#   6.02024326e+00 -2.51452943e-04  2.82083050e-10 -2.51453226e-04
#   2.51452661e-04  6.32265942e+00]
# Current V Value:  29.049115679237097
# Outside economic region: False
# Outside stability region: False
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#
#
#
#
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# Iteration # 39
# Current State Variable Values: x = [-2.71242245e-04  3.07714340e-10 -2.71242553e-04  2.71241937e-04
#   6.18167755e+00 -2.66567894e-04  2.99454177e-10 -2.66568194e-04
#   2.66567595e-04  6.49189768e+00]
# Current V Value:  30.625958084327316
# Outside economic region: False
# Outside stability region: False
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#
#
#
#
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# Iteration # 40
# Current State Variable Values: x = [-2.87087317e-04  3.26120709e-10 -2.87087643e-04  2.87086991e-04
#   6.34305082e+00 -2.82202264e-04  3.17460523e-10 -2.82202581e-04
#   2.82201946e-04  6.66105634e+00]
# Current V Value:  32.24375211011843
# Outside economic region: False
# Outside stability region: False
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#
#
#
#
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# Iteration # 41
# Current State Variable Values: x = [-3.03460768e-04  3.45179511e-10 -3.03461113e-04  3.03460423e-04
#   6.50436359e+00 -2.98363132e-04  3.36113196e-10 -2.98363468e-04
#   2.98362795e-04  6.83013601e+00]
# Current V Value:  33.902448546973375
# Outside economic region: False
# Outside stability region: False
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#
#
#
#
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# Iteration # 42
# Current State Variable Values: x = [-3.20369520e-04  3.64901700e-10 -3.20369885e-04  3.20369155e-04
#   6.66561640e+00 -3.15057666e-04  3.55423499e-10 -3.15058021e-04
#   3.15057310e-04  6.99913726e+00]
# Current V Value:  35.60199884946323
# Outside economic region: False
# Outside stability region: False
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#
#
#
#
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# Iteration # 43
# Current State Variable Values: x = [-3.37820577e-04  3.85298413e-10 -3.37820962e-04  3.37820192e-04
#   6.82680977e+00 -3.32293123e-04  3.75402939e-10 -3.32293498e-04
#   3.32292747e-04  7.16806072e+00]
# Current V Value:  37.34235514427007
# Outside economic region: False
# Outside stability region: False
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#
#
#
#
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# Iteration # 44
# Current State Variable Values: x = [-3.55821027e-04  4.06380983e-10 -3.55821433e-04  3.55820620e-04
#   6.98794423e+00 -3.50076849e-04  3.96063224e-10 -3.50077245e-04
#   3.50076453e-04  7.33690698e+00]
# Current V Value:  39.12347023820634
# Outside economic region: False
# Outside stability region: False
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#
#
#
#
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# Iteration # 45
# Current State Variable Values: x = [-3.74378044e-04  4.28160936e-10 -3.74378472e-04  3.74377616e-04
#   7.14902034e+00 -3.68416283e-04  4.17416274e-10 -3.68416701e-04
#   3.68415866e-04  7.50567667e+00]
# Current V Value:  40.945297626352016
# Outside economic region: False
# Outside stability region: False
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#
#
#
#
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# Iteration # 46
# Current State Variable Values: x = [-3.93498888e-04  4.50649997e-10 -3.93499339e-04  3.93498438e-04
#   7.31003863e+00 -3.87318955e-04  4.39474223e-10 -3.87319394e-04
#   3.87318515e-04  7.67437040e+00]
# Current V Value:  42.80779150031224
# Outside economic region: False
# Outside stability region: False
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#
#
#
#
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# Iteration # 47
# Current State Variable Values: x = [-4.13190908e-04  4.73860095e-10 -4.13191382e-04  4.13190434e-04
#   7.47099966e+00 -4.06792486e-04  4.62249420e-10 -4.06792949e-04
#   4.06792024e-04  7.84298881e+00]
# Current V Value:  44.710906756596394
# Outside economic region: False
# Outside stability region: False
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#
#
#
#
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# Iteration # 48
# Current State Variable Values: x = [-4.33461537e-04  4.97803362e-10 -4.33462035e-04  4.33461039e-04
#   7.63190399e+00 -4.26844596e-04  4.85754437e-10 -4.26845082e-04
#   4.26844110e-04  8.01153253e+00]
# Current V Value:  46.6545990051212
# Outside economic region: False
# Outside stability region: False
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#
#
#
#
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# Iteration # 49
# Current State Variable Values: x = [-4.54318301e-04  5.22492145e-10 -4.54318824e-04  4.54317779e-04
#   7.79275218e+00 -4.47483095e-04  5.10002070e-10 -4.47483605e-04
#   4.47482585e-04  8.18000220e+00]
# Current V Value:  48.63882457783961
# Outside economic region: False
# Outside stability region: False
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#
#
#
#
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# Iteration # 50
# Current State Variable Values: x = [-4.75768816e-04  5.47939002e-10 -4.75769364e-04  4.75768268e-04
#   7.95354481e+00 -4.68715893e-04  5.35005347e-10 -4.68716428e-04
#   4.68715358e-04  8.34839848e+00]
# Current V Value:  50.66354053749757
# Outside economic region: False
# Outside stability region: False
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#
#
#
#
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# Iteration # 51
# Current State Variable Values: x = [-4.97820786e-04  5.74156711e-10 -4.97821360e-04  4.97820211e-04
#   8.11428245e+00 -4.90550996e-04  5.60777530e-10 -4.90551556e-04
#   4.90550435e-04  8.51672201e+00]
# Current V Value:  52.728704686520075
# Outside economic region: False
# Outside stability region: False
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#
#
#
#
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# Iteration # 52
# Current State Variable Values: x = [-5.20482010e-04  6.01158270e-10 -5.20482611e-04  5.20481409e-04
#   8.27496569e+00 -5.12996508e-04  5.87332122e-10 -5.12997095e-04
#   5.12995921e-04  8.68497347e+00]
# Current V Value:  54.83427557602975
# Outside economic region: False
# Outside stability region: False
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#
#
#
#
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# Iteration # 53
# Current State Variable Values: x = [-5.43760380e-04  6.28956906e-10 -5.43761009e-04  5.43759751e-04
#   8.43559512e+00 -5.36060634e-04  6.14682866e-10 -5.36061249e-04
#   5.36060020e-04  8.85315352e+00]
# Current V Value:  56.98021251499925
# Outside economic region: False
# Outside stability region: False
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#
#
#
#
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# Iteration # 54
# Current State Variable Values: x = [-5.67663881e-04  6.57566077e-10 -5.67664538e-04  5.67663223e-04
#   8.59617133e+00 -5.59751680e-04  6.42843758e-10 -5.59752323e-04
#   5.59751037e-04  9.02126284e+00]
# Current V Value:  59.16647557953958
# Outside economic region: False
# Outside stability region: False
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#
#
#
#
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# Iteration # 55
# Current State Variable Values: x = [-5.92200594e-04  6.86999475e-10 -5.92201281e-04  5.92199907e-04
#   8.75669492e+00 -5.84078052e-04  6.71829047e-10 -5.84078724e-04
#   5.84077380e-04  9.18930211e+00]
# Current V Value:  61.39302562232703
# Outside economic region: False
# Outside stability region: False
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#
#
#
#
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# Iteration # 56
# Current State Variable Values: x = [-6.17378698e-04  7.17271034e-10 -6.17379415e-04  6.17377981e-04
#   8.91716651e+00 -6.09048261e-04  7.01653238e-10 -6.09048962e-04
#   6.09047559e-04  9.35727203e+00]
# Current V Value:  63.65982428217072
# Outside economic region: False
# Outside stability region: False
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#
#
#
#
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# Iteration # 57
# Current State Variable Values: x = [-6.43206466e-04  7.48394930e-10 -6.43207215e-04  6.43205718e-04
#   9.07758670e+00 -6.34670921e-04  7.32331103e-10 -6.34671653e-04
#   6.34670188e-04  9.52517329e+00]
# Current V Value:  65.96683399372313
# Outside economic region: False
# Outside stability region: False
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#
#
#
#
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# Iteration # 58
# Current State Variable Values: x = [-6.69692273e-04  7.80385591e-10 -6.69693053e-04  6.69691493e-04
#   9.23795613e+00 -6.60954752e-04  7.63877683e-10 -6.60955516e-04
#   6.60953988e-04  9.69300660e+00]
# Current V Value:  68.31401799733594
# Outside economic region: False
# Outside stability region: False
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#
#
#
#
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# Iteration # 59
# Current State Variable Values: x = [-6.96844591e-04  8.13257696e-10 -6.96845405e-04  6.96843778e-04
#   9.39827542e+00 -6.87908581e-04  7.96308292e-10 -6.87909377e-04
#   6.87907785e-04  9.86077267e+00]
# Current V Value:  70.70134034906313
# Outside economic region: False
# Outside stability region: False
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#
#
#
#
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# Iteration # 60
# Current State Variable Values: x = [-7.24671995e-04  8.47026186e-10 -7.24672842e-04  7.24671148e-04
#   9.55854521e+00 -7.15541343e-04  8.29638525e-10 -7.15542172e-04
#   7.15540513e-04  1.00284722e+01]
# Current V Value:  73.12876593081495
# Outside economic region: False
# Outside stability region: False
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#
#
#
#
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# Iteration # 61
# Current State Variable Values: x = [-7.53183161e-04  8.81706264e-10 -7.53184043e-04  7.53182279e-04
#   9.71876614e+00 -7.43862081e-04  8.63884264e-10 -7.43862945e-04
#   7.43861217e-04  1.01961060e+01]
# Current V Value:  75.59626046066394
# Outside economic region: False
# Outside stability region: False
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#
#
#
#
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# Iteration # 62
# Current State Variable Values: x = [-7.82386867e-04  9.17313404e-10 -7.82387785e-04  7.82385950e-04
#   9.87893886e+00 -7.72879950e-04  8.99061680e-10 -7.72880849e-04
#   7.72879051e-04  1.03636747e+01]
# Current V Value:  78.10379050330663
# Outside economic region: False
# Outside stability region: False
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#
#
#
#
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# Iteration # 63
# Current State Variable Values: x = [-8.12291997e-04  9.53863353e-10 -8.12292951e-04  8.12291043e-04
#   1.00390640e+01 -8.02604216e-04  9.35187245e-10 -8.02605151e-04
#   8.02603281e-04  1.05311791e+01]
# Current V Value:  80.65132348068201
# Outside economic region: False
# Outside stability region: False
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#
#
#
#
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# Iteration # 64
# Current State Variable Values: x = [-8.42907540e-04  9.91372139e-10 -8.42908531e-04  8.42906549e-04
#   1.01991423e+01 -8.33044257e-04  9.72277731e-10 -8.33045229e-04
#   8.33043285e-04  1.06986200e+01]
# Current V Value:  83.23882768275166
# Outside economic region: False
# Outside stability region: False
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#
#
#
#
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# Iteration # 65
# Current State Variable Values: x = [-8.74242590e-04  1.02985607e-09 -8.74243620e-04  8.74241561e-04
#   1.03591743e+01 -8.64209567e-04  1.01035022e-09 -8.64210577e-04
#   8.64208557e-04  1.08659980e+01]
# Current V Value:  85.86627227844251
# Outside economic region: False
# Outside stability region: False
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#
#
#
#
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# Iteration # 66
# Current State Variable Values: x = [-9.06306352e-04  1.06933176e-09 -9.06307421e-04  9.06305283e-04
#   1.05191608e+01 -8.96109754e-04  1.04942211e-09 -8.96110804e-04
#   8.96108705e-04  1.10333141e+01]
# Current V Value:  88.5336273267549
# Outside economic region: False
# Outside stability region: False
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#
#
#
#
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# Iteration # 67
# Current State Variable Values: x = [-9.39108137e-04  1.10981610e-09 -9.39109247e-04  9.39107027e-04
#   1.06791025e+01 -9.28754544e-04  1.08951113e-09 -9.28755634e-04
#   9.28753455e-04  1.12005689e+01]
# Current V Value:  91.24086378804083
# Outside economic region: False
# Outside stability region: False
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#
#
#
#
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# Iteration # 68
# Current State Variable Values: x = [-9.72657367e-04  1.15132630e-09 -9.72658518e-04  9.72656216e-04
#   1.08390000e+01 -9.62153781e-04  1.13063533e-09 -9.62154912e-04
#   9.62152651e-04  1.13677632e+01]
# Current V Value:  93.98795353545226
# Outside economic region: False
# Outside stability region: False
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#
#
#
#
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# Iteration # 69
# Current State Variable Values: x = [-1.00696358e-03  1.19387986e-09 -1.00696477e-03  1.00696238e-03
#   1.09988540e+01 -9.96317428e-04  1.17281309e-09 -9.96318601e-04
#   9.96316256e-04  1.15348978e+01]
# Current V Value:  96.77486936656493
# Outside economic region: False
# Outside stability region: False
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#
#
#
#
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# Iteration # 70
# Current State Variable Values: x = [-1.04203641e-03  1.23749462e-09 -1.04203765e-03  1.04203518e-03
#   1.11586653e+01 -1.03125557e-03  1.21606314e-09 -1.03125679e-03
#   1.03125435e-03  1.17019736e+01]
# Current V Value:  99.60158501517947
# Outside economic region: False
# Outside stability region: False
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#
#
#
#
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# Iteration # 71
# Current State Variable Values: x = [-1.07788564e-03  1.28218871e-09 -1.07788692e-03  1.07788436e-03
#   1.13184345e+01 -1.06697841e-03  1.26040456e-09 -1.06697967e-03
#   1.06697715e-03  1.18689914e+01]
# Current V Value:  102.46807516330311
# Outside economic region: False
# Outside stability region: False
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#
#
#
#
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# Iteration # 72
# Current State Variable Values: x = [-1.11452112e-03  1.32798063e-09 -1.11452245e-03  1.11451980e-03
#   1.14781624e+01 -1.10349629e-03  1.30585678e-09 -1.10349760e-03
#   1.10349498e-03  1.20359518e+01]
# Current V Value:  105.37431545331535
# Outside economic region: False
# Outside stability region: False
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#
#
#
#
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# Iteration # 73
# Current State Variable Values: x = [-1.15195287e-03  1.37488917e-09 -1.15195424e-03  1.15195149e-03
#   1.16378497e+01 -1.14081965e-03  1.35243962e-09 -1.14082101e-03
#   1.14081830e-03  1.22028559e+01]
# Current V Value:  108.32028250032101
# Outside economic region: False
# Outside stability region: False
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#
#
#
#
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# Iteration # 74
# Current State Variable Values: x = [-1.19019098e-03  1.42293348e-09 -1.19019240e-03  1.19018956e-03
#   1.17974972e+01 -1.17895909e-03  1.40017324e-09 -1.17896049e-03
#   1.17895769e-03  1.23697044e+01]
# Current V Value:  111.30595390469225
# Outside economic region: False
# Outside stability region: False
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#
#
#
#
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# Iteration # 75
# Current State Variable Values: x = [-1.22924569e-03  1.47213306e-09 -1.22924716e-03  1.22924422e-03
#   1.19571056e+01 -1.21792531e-03  1.44907819e-09 -1.21792676e-03
#   1.21792386e-03  1.25364982e+01]
# Current V Value:  114.33130826480581
# Outside economic region: False
# Outside stability region: False
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#
#
#
#
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# Iteration # 76
# Current State Variable Values: x = [-1.26912735e-03  1.52250776e-09 -1.26912887e-03  1.26912582e-03
#   1.21166756e+01 -1.25772915e-03  1.49917542e-09 -1.25773065e-03
#   1.25772765e-03  1.27032381e+01]
# Current V Value:  117.39632518997628
# Outside economic region: False
# Outside stability region: False
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#
#
#
#
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# Iteration # 77
# Current State Variable Values: x = [-1.30984643e-03  1.57407781e-09 -1.30984800e-03  1.30984485e-03
#   1.22762080e+01 -1.29838158e-03  1.55048625e-09 -1.29838313e-03
#   1.29838003e-03  1.28699250e+01]
# Current V Value:  120.50098531359015
# Outside economic region: False
# Outside stability region: False
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#
#
#
#
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# Iteration # 78
# Current State Variable Values: x = [-1.35141352e-03  1.62686377e-09 -1.35141515e-03  1.35141190e-03
#   1.24357037e+01 -1.33989372e-03  1.60303245e-09 -1.33989532e-03
#   1.33989211e-03  1.30365597e+01]
# Current V Value:  123.64527030644469
# Outside economic region: False
# Outside stability region: False
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#
#
#
#
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# Iteration # 79
# Current State Variable Values: x = [-1.39383936e-03  1.68088660e-09 -1.39384104e-03  1.39383768e-03
#   1.25951633e+01 -1.38227679e-03  1.65683615e-09 -1.38227844e-03
#   1.38227513e-03  1.32031432e+01]
# Current V Value:  126.82916289029299
# Outside economic region: False
# Outside stability region: False
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#
#
#
#
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# Iteration # 80
# Current State Variable Values: x = [-1.43713479e-03  1.73616766e-09 -1.43713652e-03  1.43713305e-03
#   1.27545876e+01 -1.42554217e-03  1.71191993e-09 -1.42554388e-03
#   1.42554046e-03  1.33696764e+01]
# Current V Value:  130.05264685160247
# Outside economic region: False
# Outside stability region: False
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#
#
#
#
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# Iteration # 81
# Current State Variable Values: x = [-1.48131078e-03  1.79272868e-09 -1.48131257e-03  1.48130899e-03
#   1.29139775e+01 -1.46970138e-03  1.76830681e-09 -1.46970315e-03
#   1.46969961e-03  1.35361600e+01]
# Current V Value:  133.31570705552764
# Outside economic region: False
# Outside stability region: False
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#
#
#
#
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# Iteration # 82
# Current State Variable Values: x = [-1.52637844e-03  1.85059179e-09 -1.52638029e-03  1.52637659e-03
#   1.30733338e+01 -1.51476606e-03  1.82602022e-09 -1.51476789e-03
#   1.51476424e-03  1.37025952e+01]
# Current V Value:  136.61832946010134
# Outside economic region: False
# Outside stability region: False
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#
#
#
#
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# Iteration # 83
# Current State Variable Values: x = [-1.57234901e-03  1.90977953e-09 -1.57235092e-03  1.57234710e-03
#   1.32326573e+01 -1.56074802e-03  1.88508406e-09 -1.56074990e-03
#   1.56074613e-03  1.38689827e+01]
# Current V Value:  139.96050113065144
# Outside economic region: False
# Outside stability region: False
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#
#
#
#
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# Iteration # 84
# Current State Variable Values: x = [-1.61923385e-03  1.97031488e-09 -1.61923582e-03  1.61923188e-03
#   1.33919487e+01 -1.60765917e-03  1.94552269e-09 -1.60766112e-03
#   1.60765723e-03  1.40353235e+01]
# Current V Value:  143.34221025444288
# Outside economic region: False
# Outside stability region: False
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#
#
#
#
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# Iteration # 85
# Current State Variable Values: x = [-1.66704446e-03  2.03222122e-09 -1.66704649e-03  1.66704243e-03
#   1.35512090e+01 -1.65551161e-03  2.00736093e-09 -1.65551362e-03
#   1.65550960e-03  1.42016186e+01]
# Current V Value:  146.76344615555112
# Outside economic region: False
# Outside stability region: False
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#
#
#
#
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# Iteration # 86
# Current State Variable Values: x = [-1.71579249e-03  2.09552236e-09 -1.71579459e-03  1.71579040e-03
#   1.37104389e+01 -1.70431755e-03  2.07062408e-09 -1.70431962e-03
#   1.70431548e-03  1.43678688e+01]
# Current V Value:  150.22419930997305
# Outside economic region: False
# Outside stability region: False
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#
#
#
#
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# Iteration # 87
# Current State Variable Values: x = [-1.76548971e-03  2.16024258e-09 -1.76549187e-03  1.76548755e-03
#   1.38696394e+01 -1.75408937e-03  2.13533794e-09 -1.75409151e-03
#   1.75408723e-03  1.45340753e+01]
# Current V Value:  153.72446136097625
# Outside economic region: False
# Outside stability region: False
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#
#
#
#
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# Iteration # 88
# Current State Variable Values: x = [-1.81614803e-03  2.22640660e-09 -1.81615025e-03  1.81614580e-03
#   1.40288113e+01 -1.80483959e-03  2.20152879e-09 -1.80484179e-03
#   1.80483738e-03  1.47002388e+01]
# Current V Value:  157.26422513469387
# Outside economic region: False
# Outside stability region: False
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#
#
#
#
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# Iteration # 89
# Current State Variable Values: x = [-1.86777950e-03  2.29403958e-09 -1.86778180e-03  1.86777721e-03
#   1.41879554e+01 -1.85658087e-03  2.26922343e-09 -1.85658314e-03
#   1.85657860e-03  1.48663605e+01]
# Current V Value:  160.8434846559677
# Outside economic region: False
# Outside stability region: False
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#
#
#
#
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# Iteration # 90
# Current State Variable Values: x = [-1.92039633e-03  2.36316719e-09 -1.92039869e-03  1.92039396e-03
#   1.43470726e+01 -1.90932605e-03  2.33844919e-09 -1.90932839e-03
#   1.90932372e-03  1.50324413e+01]
# Current V Value:  164.46223516444573
# Outside economic region: False
# Outside stability region: False
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#
#
#
#
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# Iteration # 91
# Current State Variable Values: x = [-1.97401084e-03  2.43381557e-09 -1.97401327e-03  1.97400840e-03
#   1.45061639e+01 -1.96308811e-03  2.40923393e-09 -1.96309052e-03
#   1.96308570e-03  1.51984822e+01]
# Current V Value:  168.1204731309379
# Outside economic region: False
# Outside stability region: False
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#
#
#
#
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# Iteration # 92
# Current State Variable Values: x = [-2.02863552e-03  2.50601132e-09 -2.02863803e-03  2.02863302e-03
#   1.46652301e+01 -2.01788018e-03  2.48160603e-09 -2.01788266e-03
#   2.01787769e-03  1.53644843e+01]
# Current V Value:  171.81819627403507
# Outside economic region: False
# Outside stability region: False
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#
#
#
#
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# Iteration # 93
# Current State Variable Values: x = [-2.08428301e-03  2.57978159e-09 -2.08428559e-03  2.08428043e-03
#   1.48242721e+01 -2.07371555e-03  2.55559447e-09 -2.07371810e-03
#   2.07371299e-03  1.55304485e+01]
# Current V Value:  175.555403576997
# Outside economic region: False
# Outside stability region: False
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#
#
#
#
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# Iteration # 94
# Current State Variable Values: x = [-2.14096608e-03  2.65515401e-09 -2.14096874e-03  2.14096343e-03
#   1.49832908e+01 -2.13060768e-03  2.63122877e-09 -2.13061031e-03
#   2.13060504e-03  1.56963759e+01]
# Current V Value:  179.33209530491285
# Outside economic region: False
# Outside stability region: False
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#
#
#
#
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# Iteration # 95
# Current State Variable Values: x = [-2.19869767e-03  2.73215675e-09 -2.19870040e-03  2.19869494e-03
#   1.51422873e+01 -2.18857018e-03  2.70853903e-09 -2.18857289e-03
#   2.18856747e-03  1.58622676e+01]
# Current V Value:  183.14827302214132
# Outside economic region: False
# Outside stability region: False
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#
#
#
#
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# Iteration # 96
# Current State Variable Values: x = [-2.25749085e-03  2.81081852e-09 -2.25749366e-03  2.25748804e-03
#   1.53012623e+01 -2.24761685e-03  2.78755595e-09 -2.24761963e-03
#   2.24761406e-03  1.60281246e+01]
# Current V Value:  187.00393961003417
# Outside economic region: False
# Outside stability region: False
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#
#
#
#
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# Iteration # 97
# Current State Variable Values: x = [-2.31735886e-03  2.89116854e-09 -2.31736175e-03  2.31735597e-03
#   1.54602169e+01 -2.30776162e-03  2.86831085e-09 -2.30776448e-03
#   2.30775875e-03  1.61939480e+01]
# Current V Value:  190.89909928494967
# Outside economic region: False
# Outside stability region: False
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#
#
#
#
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# Iteration # 98
# Current State Variable Values: x = [-2.37831509e-03  2.97323664e-09 -2.37831807e-03  2.37831212e-03
#   1.56191520e+01 -2.36901861e-03  2.95083565e-09 -2.36902156e-03
#   2.36901566e-03  1.63597388e+01]
# Current V Value:  194.83375761656072
# Outside economic region: False
# Outside stability region: False
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#
#
#
#
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# Iteration # 99
# Current State Variable Values: x = [-2.44037310e-03  3.05705318e-09 -2.44037616e-03  2.44037004e-03
#   1.57780687e+01 -2.43140210e-03  3.03516292e-09 -2.43140514e-03
#   2.43139907e-03  1.65254982e+01]
# Current V Value:  198.80792154646394
# Outside economic region: False
# Outside stability region: False
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#
#
#
#
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# Iteration # 100
# Current State Variable Values: x = [-2.50354659e-03  3.14264913e-09 -2.50354973e-03  2.50354345e-03
#   1.59369678e+01 -2.49492656e-03  3.12132586e-09 -2.49492968e-03
#   2.49492344e-03  1.66912273e+01]
# Current V Value:  202.8215994070957
# Outside economic region: False
# Outside stability region: False
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#
#
#
#
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# Iteration # 101
# Current State Variable Values: x = [-2.56784943e-03  3.23005602e-09 -2.56785266e-03  2.56784620e-03
#   1.60958503e+01 -2.55960662e-03  3.20935837e-09 -2.55960983e-03
#   2.55960341e-03  1.68569273e+01]
# Current V Value:  206.87480094095994
# Outside economic region: False
# Outside stability region: False
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#
#
#
#
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# Iteration # 102
# Current State Variable Values: x = [-2.63329565e-03  3.31930603e-09 -2.63329897e-03  2.63329233e-03
#   1.62547174e+01 -2.62545708e-03  3.29929498e-09 -2.62546038e-03
#   2.62545378e-03  1.70225991e+01]
# Current V Value:  210.96753732017615
# Outside economic region: False
# Outside stability region: False
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#
#
#
#
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# Iteration # 103
# Current State Variable Values: x = [-2.69989946e-03  3.41043193e-09 -2.69990288e-03  2.69989605e-03
#   1.64135699e+01 -2.69249294e-03  3.39117094e-09 -2.69249633e-03
#   2.69248955e-03  1.71882440e+01]
# Current V Value:  215.09982116635166
# Outside economic region: False
# Outside stability region: False
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#
#
#
#
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# Iteration # 104
# Current State Variable Values: x = [-2.76767523e-03  3.50346714e-09 -2.76767873e-03  2.76767172e-03
#   1.65724089e+01 -2.76072936e-03  3.48502222e-09 -2.76073284e-03
#   2.76072587e-03  1.73538632e+01]
# Current V Value:  219.2716665707838
# Outside economic region: False
# Outside stability region: False
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#
#
#
#
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# Iteration # 105
# Current State Variable Values: x = [-2.83663748e-03  3.59844572e-09 -2.83664107e-03  2.83663388e-03
#   1.67312354e+01 -2.83018169e-03  3.58088549e-09 -2.83018527e-03
#   2.83017811e-03  1.75194578e+01]
# Current V Value:  223.4830891150038
# Outside economic region: False
# Outside stability region: False
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#
#
#
#
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# Iteration # 106
# Current State Variable Values: x = [-2.90680092e-03  3.69540239e-09 -2.90680462e-03  2.90679722e-03
#   1.68900506e+01 -2.90086547e-03  3.67879818e-09 -2.90086915e-03
#   2.90086179e-03  1.76850290e+01]
# Current V Value:  227.73410589166303
# Outside economic region: False
# Outside stability region: False
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#
#
#
#
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# Iteration # 107
# Current State Variable Values: x = [-2.97818044e-03  3.79437256e-09 -2.97818423e-03  2.97817665e-03
#   1.70488554e+01 -2.97279643e-03  3.77879846e-09 -2.97280021e-03
#   2.97279265e-03  1.78505779e+01]
# Current V Value:  232.02473552576976
# Outside economic region: False
# Outside stability region: False
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#
#
#
#
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# Iteration # 108
# Current State Variable Values: x = [-3.05079109e-03  3.89539232e-09 -3.05079499e-03  3.05078720e-03
#   1.72076509e+01 -3.04599048e-03  3.88092529e-09 -3.04599436e-03
#   3.04598660e-03  1.80161059e+01]
# Current V Value:  236.3549981962874
# Outside economic region: False
# Outside stability region: False
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#
#
#
#
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# Iteration # 109
# Current State Variable Values: x = [-3.12464811e-03  3.99849846e-09 -3.12465211e-03  3.12464411e-03
#   1.73664382e+01 -3.12046372e-03  3.98521842e-09 -3.12046771e-03
#   3.12045974e-03  1.81816142e+01]
# Current V Value:  240.72491565809776
# Outside economic region: False
# Outside stability region: False
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#
#
#
#
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# Iteration # 110
# Current State Variable Values: x = [-3.19976691e-03  4.10372852e-09 -3.19977101e-03  3.19976280e-03
#   1.75252185e+01 -3.19623247e-03  4.09171842e-09 -3.19623656e-03
#   3.19622838e-03  1.83471039e+01]
# Current V Value:  245.13451126433645
# Outside economic region: False
# Outside stability region: False
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#
#
#
#
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# Iteration # 111
# Current State Variable Values: x = [-3.27616308e-03  4.21112074e-09 -3.27616729e-03  3.27615887e-03
#   1.76839927e+01 -3.27331322e-03  4.20046666e-09 -3.27331742e-03
#   3.27330901e-03  1.85125763e+01]
# Current V Value:  249.58380998911014
# Outside economic region: False
# Outside stability region: False
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#
#
#
#
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# Iteration # 112
# Current State Variable Values: x = [-3.35385241e-03  4.32071415e-09 -3.35385673e-03  3.35384809e-03
#   1.78427621e+01 -3.35172266e-03  4.31150539e-09 -3.35172697e-03
#   3.35171835e-03  1.86780327e+01]
# Current V Value:  254.0728384506055
# Outside economic region: False
# Outside stability region: False
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#
#
#
#
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# Iteration # 113
# Current State Variable Values: x = [-3.43285086e-03  4.43254853e-09 -3.43285529e-03  3.43284643e-03
#   1.80015277e+01 -3.43147770e-03  4.42487771e-09 -3.43148213e-03
#   3.43147328e-03  1.88434744e+01]
# Current V Value:  258.6016249345878
# Outside economic region: False
# Outside stability region: False
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#
#
#
#
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# Iteration # 114
# Current State Variable Values: x = [-3.51317459e-03  4.54666444e-09 -3.51317914e-03  3.51317005e-03
#   1.81602908e+01 -3.51259545e-03  4.54062763e-09 -3.51259999e-03
#   3.51259091e-03  1.90089027e+01]
# Current V Value:  263.17019941831165
# Outside economic region: False
# Outside stability region: False
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#
#
#
#
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# Iteration # 115
# Current State Variable Values: x = [-3.59483995e-03  4.66310329e-09 -3.59484461e-03  3.59483529e-03
#   1.83190524e+01 -3.59509321e-03  4.65880003e-09 -3.59509787e-03
#   3.59508855e-03  1.91743189e+01]
# Current V Value:  267.77859359484074
# Outside economic region: False
# Outside stability region: False
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#
#
#
#
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# Iteration # 116
# Current State Variable Values: x = [-3.67786348e-03  4.78190726e-09 -3.67786826e-03  3.67785869e-03
#   1.84778137e+01 -3.67898852e-03  4.77944077e-09 -3.67899330e-03
#   3.67898374e-03  1.93397243e+01]
# Current V Value:  272.42684089779027
# Outside economic region: False
# Outside stability region: False
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#
#
#
#
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# Iteration # 117
# Current State Variable Values: x = [-3.76226190e-03  4.90311940e-09 -3.76226681e-03  3.76225700e-03
#   1.86365760e+01 -3.76429910e-03  4.90259661e-09 -3.76430401e-03
#   3.76429420e-03  1.95051202e+01]
# Current V Value:  277.1149765265
# Outside economic region: False
# Outside stability region: False
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#
#
#
#
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# Iteration # 118
# Current State Variable Values: x = [-3.84805217e-03  5.02678362e-09 -3.84805720e-03  3.84804714e-03
#   1.87953404e+01 -3.85104292e-03  5.02831532e-09 -3.85104795e-03
#   3.85103789e-03  1.96705080e+01]
# Current V Value:  281.84303747164756
# Outside economic region: False
# Outside stability region: False
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#
#
#
#
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# Iteration # 119
# Current State Variable Values: x = [-3.93525141e-03  5.15294470e-09 -3.93525657e-03  3.93524626e-03
#   1.89541081e+01 -3.93923813e-03  5.15664566e-09 -3.93924328e-03
#   3.93923297e-03  1.98358892e+01]
# Current V Value:  286.61106254130897
# Outside economic region: False
# Outside stability region: False
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#
#
#
#
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# Iteration # 120
# Current State Variable Values: x = [-4.02387697e-03  5.28164834e-09 -4.02388225e-03  4.02387169e-03
#   1.91128804e+01 -4.02890313e-03  5.28763739e-09 -4.02890841e-03
#   4.02889784e-03  2.00012649e+01]
# Current V Value:  291.41909238747917
# Outside economic region: False
# Outside stability region: False
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#
#
#
#
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# Iteration # 121
# Current State Variable Values: x = [-4.11394638e-03  5.41294115e-09 -4.11395180e-03  4.11394097e-03
#   1.92716585e+01 -4.12005653e-03  5.42134134e-09 -4.12006195e-03
#   4.12005110e-03  2.01666368e+01]
# Current V Value:  296.26716953305714
# Outside economic region: False
# Outside stability region: False
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#
#
#
#
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# Iteration # 122
# Current State Variable Values: x = [-4.20547741e-03  5.54687066e-09 -4.20548296e-03  4.20547187e-03
#   1.94304436e+01 -4.21271717e-03  5.55780939e-09 -4.21272273e-03
#   4.21271161e-03  2.03320061e+01]
# Current V Value:  301.1553383993134
# Outside economic region: False
# Outside stability region: False
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#
#
#
#
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# Iteration # 123
# Current State Variable Values: x = [-4.29848802e-03  5.68348540e-09 -4.29849370e-03  4.29848234e-03
#   1.95892370e+01 -4.30690412e-03  5.69709452e-09 -4.30690982e-03
#   4.30689843e-03  2.04973744e+01]
# Current V Value:  306.08364533384076
# Outside economic region: False
# Outside stability region: False
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#
#
#
#
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# Iteration # 124
# Current State Variable Values: x = [-4.39299639e-03  5.82283486e-09 -4.39300221e-03  4.39299056e-03
#   1.97480401e+01 -4.40263669e-03  5.83925082e-09 -4.40264253e-03
#   4.40263085e-03  2.06627430e+01]
# Current V Value:  311.0521386390065
# Outside economic region: False
# Outside stability region: False
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#
#
#
#
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# Iteration # 125
# Current State Variable Values: x = [-4.48902091e-03  5.96496955e-09 -4.48902687e-03  4.48901494e-03
#   1.99068540e+01 -4.49993442e-03  5.98433355e-09 -4.49994040e-03
#   4.49992843e-03  2.08281134e+01]
# Current V Value:  316.0608686009116
# Outside economic region: False
# Outside stability region: False
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#
#
#
#
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# Iteration # 126
# Current State Variable Values: x = [-4.58658019e-03  6.10994099e-09 -4.58658630e-03  4.58657408e-03
#   2.00656802e+01 -4.59881707e-03  6.13239911e-09 -4.59882320e-03
#   4.59881094e-03  2.09934872e+01]
# Current V Value:  321.10988751887203
# Outside economic region: False
# Outside stability region: False
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#
#
#
#
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# Iteration # 127
# Current State Variable Values: x = [-4.68569309e-03  6.25780179e-09 -4.68569935e-03  4.68568683e-03
#   2.02245199e+01 -4.69930468e-03  6.28350511e-09 -4.69931096e-03
#   4.69929839e-03  2.11588658e+01]
# Current V Value:  326.19924973542714
# Outside economic region: False
# Outside stability region: False
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#
#
#
#
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# ...
# Iteration # 7159
# Current State Variable Values: x = [-9.26864313e-01  4.60929630e-05 -9.26910406e-01  9.26818220e-01
#   5.04938268e+01 -1.77759981e+00  2.88927782e-04 -1.77788874e+00
#   1.77731089e+00  1.00476034e+02]
# Current V Value:  12756.900193110534
# Outside economic region: False
# Outside stability region: False
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#
#
#
#
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# Iteration # 7160
# Current State Variable Values: x = [-9.26864367e-01  4.60934598e-05 -9.26910461e-01  9.26818274e-01
#   5.05010655e+01 -1.77759887e+00  2.88927945e-04 -1.77788780e+00
#   1.77730995e+00  1.00499351e+02]
# Current V Value:  12759.421278385013
# Outside economic region: False
# Outside stability region: False
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#
#
#
#
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# Iteration # 7161
# Current State Variable Values: x = [-9.26864389e-01  4.60939545e-05 -9.26910483e-01  9.26818295e-01
#   5.04920794e+01 -1.77760009e+00  2.88928604e-04 -1.77788902e+00
#   1.77731116e+00  1.00522790e+02]
# Current V Value:  12761.55690090293
# Outside economic region: False
# Outside stability region: False
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#
#
#
#
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# Iteration # 7162
# Current State Variable Values: x = [-9.26864372e-01  4.60944466e-05 -9.26910466e-01  9.26818277e-01
#   5.04993145e+01 -1.77760111e+00  2.88929219e-04 -1.77789004e+00
#   1.77731218e+00  1.00495013e+02]
# Current V Value:  12758.953069904812
# Outside economic region: False
# Outside stability region: False
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#
#
#
#
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# Iteration # 7163
# Current State Variable Values: x = [-9.26864648e-01  4.60949552e-05 -9.26910743e-01  9.26818553e-01
#   5.05065650e+01 -1.77760190e+00  2.88929781e-04 -1.77789083e+00
#   1.77731297e+00  1.00518432e+02]
# Current V Value:  12761.495523841242
# Outside economic region: False
# Outside stability region: False
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#
#
#
#
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# Iteration # 7164
# Current State Variable Values: x = [-9.26864892e-01  4.60954617e-05 -9.26910988e-01  9.26818797e-01
#   5.04975905e+01 -1.77760250e+00  2.88930301e-04 -1.77789143e+00
#   1.77731357e+00  1.00490634e+02]
# Current V Value:  12758.479555911712
# Outside economic region: False
# Outside stability region: False
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#
#
#
#
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# Iteration # 7165
# Current State Variable Values: x = [-9.26865098e-01  4.60959657e-05 -9.26911194e-01  9.26819002e-01
#   5.05048373e+01 -1.77760287e+00  2.88930767e-04 -1.77789180e+00
#   1.77731394e+00  1.00514028e+02]
# Current V Value:  12761.016712288181
# Outside economic region: False
# Outside stability region: False
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#
#
#
#
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# Iteration # 7166
# Current State Variable Values: x = [-9.26865271e-01  4.60964676e-05 -9.26911368e-01  9.26819175e-01
#   5.04958592e+01 -1.77760306e+00  2.88931190e-04 -1.77789199e+00
#   1.77731413e+00  1.00486205e+02]
# Current V Value:  12757.99571384963
# Outside economic region: False
# Outside stability region: False
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#
#
#
#
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# Iteration # 7167
# Current State Variable Values: x = [-9.26865406e-01  4.60969670e-05 -9.26911503e-01  9.26819309e-01
#   5.05031023e+01 -1.77760302e+00  2.88931561e-04 -1.77789195e+00
#   1.77731409e+00  1.00509575e+02]
# Current V Value:  12760.52762644506
# Outside economic region: False
# Outside stability region: False
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#
#
#
#
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# Iteration # 7168
# Current State Variable Values: x = [-9.26865509e-01  4.60974643e-05 -9.26911607e-01  9.26819412e-01
#   5.04941205e+01 -1.77760280e+00  2.88931890e-04 -1.77789173e+00
#   1.77731386e+00  1.00481728e+02]
# Current V Value:  12757.501653596468
# Outside economic region: False
# Outside stability region: False
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#
#
#
#
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# Iteration # 7169
# Current State Variable Values: x = [-9.26865574e-01  4.60979591e-05 -9.26911672e-01  9.26819476e-01
#   5.05013598e+01 -1.77760235e+00  2.88932166e-04 -1.77789128e+00
#   1.77731342e+00  1.00505072e+02]
# Current V Value:  12760.028375648213
# Outside economic region: False
# Outside stability region: False
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#
#
#
#
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# Iteration # 7170
# Current State Variable Values: x = [-9.26865606e-01  4.60984517e-05 -9.26911704e-01  9.26819507e-01
#   5.04923743e+01 -1.77760172e+00  2.88932400e-04 -1.77789065e+00
#   1.77731279e+00  1.00477201e+02]
# Current V Value:  12756.997483917512
# Outside economic region: False
# Outside stability region: False
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#
#
#
#
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# Iteration # 7171
# Current State Variable Values: x = [-9.26865599e-01  4.60989419e-05 -9.26911698e-01  9.26819500e-01
#   5.04996099e+01 -1.77760087e+00  2.88932582e-04 -1.77788980e+00
#   1.77731193e+00  1.00500522e+02]
# Current V Value:  12759.519068125355
# Outside economic region: False
# Outside stability region: False
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#
#
#
#
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# Iteration # 7172
# Current State Variable Values: x = [-9.26865886e-01  4.60994485e-05 -9.26911985e-01  9.26819786e-01
#   5.05068610e+01 -1.77759984e+00  2.88932722e-04 -1.77788877e+00
#   1.77731090e+00  1.00472631e+02]
# Current V Value:  12756.895502036034
# Outside economic region: False
# Outside stability region: False
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#
#
#
#
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# Iteration # 7173
# Current State Variable Values: x = [-9.26866140e-01  4.60999529e-05 -9.26912240e-01  9.26820040e-01
#   5.04978871e+01 -1.77759859e+00  2.88932810e-04 -1.77788752e+00
#   1.77730965e+00  1.00495933e+02]
# Current V Value:  12759.004980374193
# Outside economic region: False
# Outside stability region: False
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#
#
#
#
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# Iteration # 7174
# Current State Variable Values: x = [-9.26866356e-01  4.61004549e-05 -9.26912457e-01  9.26820256e-01
#   5.05051345e+01 -1.77759949e+00  2.88933395e-04 -1.77788842e+00
#   1.77731055e+00  1.00519358e+02]
# Current V Value:  12761.548248112356
# Outside economic region: False
# Outside stability region: False
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#
#
#
#
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# Iteration # 7175
# Current State Variable Values: x = [-9.26866540e-01  4.61009548e-05 -9.26912641e-01  9.26820440e-01
#   5.04961569e+01 -1.77760020e+00  2.88933936e-04 -1.77788914e+00
#   1.77731127e+00  1.00491566e+02]
# Current V Value:  12758.533048671916
# Outside economic region: False
# Outside stability region: False
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#
#
#
#
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# Iteration # 7176
# Current State Variable Values: x = [-9.26866686e-01  4.61014522e-05 -9.26912787e-01  9.26820584e-01
#   5.05034006e+01 -1.77760069e+00  2.88934425e-04 -1.77788962e+00
#   1.77731175e+00  1.00514965e+02]
# Current V Value:  12761.071000141028
# Outside economic region: False
# Outside stability region: False
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#
#
#
#
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# Iteration # 7177
# Current State Variable Values: x = [-9.26866799e-01  4.61019475e-05 -9.26912901e-01  9.26820697e-01
#   5.04944193e+01 -1.77760098e+00  2.88934870e-04 -1.77788992e+00
#   1.77731205e+00  1.00487148e+02]
# Current V Value:  12758.050751049701
# Outside economic region: False
# Outside stability region: False
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#
#
#
#
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# Iteration # 7178
# Current State Variable Values: x = [-9.26866874e-01  4.61024403e-05 -9.26912977e-01  9.26820772e-01
#   5.05016593e+01 -1.77760105e+00  2.88935263e-04 -1.77788999e+00
#   1.77731212e+00  1.00510523e+02]
# Current V Value:  12760.583440211178
# Outside economic region: False
# Outside stability region: False
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#
#
#
#
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# Iteration # 7179
# Current State Variable Values: x = [-9.26866917e-01  4.61029309e-05 -9.26913020e-01  9.26820814e-01
#   5.04926743e+01 -1.77760094e+00  2.88935614e-04 -1.77788988e+00
#   1.77731200e+00  1.00482681e+02]
# Current V Value:  12757.558197760032
# Outside economic region: False
# Outside stability region: False
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#
#
#
#
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# Iteration # 7180
# Current State Variable Values: x = [-9.26866921e-01  4.61034191e-05 -9.26913024e-01  9.26820817e-01
#   5.04999105e+01 -1.77760060e+00  2.88935912e-04 -1.77788954e+00
#   1.77731166e+00  1.00506032e+02]
# Current V Value:  12760.08567803219
# Outside economic region: False
# Outside stability region: False
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#
#
#
#
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# Iteration # 7181
# Current State Variable Values: x = [-9.26867218e-01  4.61039237e-05 -9.26913322e-01  9.26821114e-01
#   5.05071622e+01 -1.77760008e+00  2.88936168e-04 -1.77788902e+00
#   1.77731114e+00  1.00478171e+02]
# Current V Value:  12757.46769001723
# Outside economic region: False
# Outside stability region: False
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#
#
#
#
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# Iteration # 7182
# Current State Variable Values: x = [-9.26867483e-01  4.61044262e-05 -9.26913587e-01  9.26821378e-01
#   5.04981889e+01 -1.77759934e+00  2.88936371e-04 -1.77788827e+00
#   1.77731040e+00  1.00501502e+02]
# Current V Value:  12759.582991719162
# Outside economic region: False
# Outside stability region: False
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#
#
#
#
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# Iteration # 7183
# Current State Variable Values: x = [-9.26867709e-01  4.61049262e-05 -9.26913814e-01  9.26821605e-01
#   5.05054369e+01 -1.77759841e+00  2.88936533e-04 -1.77788735e+00
#   1.77730948e+00  1.00473617e+02]
# Current V Value:  12756.960124535668
# Outside economic region: False
# Outside stability region: False
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#
#
#
#
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# Iteration # 7184
# Current State Variable Values: x = [-9.26867904e-01  4.61054241e-05 -9.26914010e-01  9.26821799e-01
#   5.04964599e+01 -1.77759727e+00  2.88936644e-04 -1.77788621e+00
#   1.77730833e+00  1.00496924e+02]
# Current V Value:  12759.070354582038
# Outside economic region: False
# Outside stability region: False
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#
#
#
#
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# Iteration # 7185
# Current State Variable Values: x = [-9.26868060e-01  4.61059195e-05 -9.26914166e-01  9.26821954e-01
#   5.05037042e+01 -1.77759828e+00  2.88937250e-04 -1.77788722e+00
#   1.77730934e+00  1.00520354e+02]
# Current V Value:  12761.61435534763
# Outside economic region: False
# Outside stability region: False
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#
#
#
#
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# Iteration # 7186
# Current State Variable Values: x = [-9.26868184e-01  4.61064128e-05 -9.26914291e-01  9.26822078e-01
#   5.04947235e+01 -1.77759910e+00  2.88937813e-04 -1.77788804e+00
#   1.77731016e+00  1.00492567e+02]
# Current V Value:  12758.599840459032
# Outside economic region: False
# Outside stability region: False
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#
#
#
#
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# Iteration # 7187
# Current State Variable Values: x = [-9.26868269e-01  4.61069036e-05 -9.26914376e-01  9.26822163e-01
#   5.05019640e+01 -1.77759969e+00  2.88938322e-04 -1.77788863e+00
#   1.77731075e+00  1.00515971e+02]
# Current V Value:  12761.138507027363
# Outside economic region: False
# Outside stability region: False
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#
#
#
#
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# Iteration # 7188
# Current State Variable Values: x = [-9.26868323e-01  4.61073923e-05 -9.26914430e-01  9.26822215e-01
#   5.04929796e+01 -1.77760009e+00  2.88938789e-04 -1.77788903e+00
#   1.77731115e+00  1.00488160e+02]
# Current V Value:  12758.118924170276
# Outside economic region: False
# Outside stability region: False
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#
#
#
#
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# Iteration # 7189
# Current State Variable Values: x = [-9.26868337e-01  4.61078785e-05 -9.26914445e-01  9.26822229e-01
#   5.05002164e+01 -1.77760026e+00  2.88939203e-04 -1.77788920e+00
#   1.77731132e+00  1.00511539e+02]
# Current V Value:  12760.652310678479
# Outside economic region: False
# Outside stability region: False
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#
#
#
#
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# Iteration # 7190
# Current State Variable Values: x = [-9.26868320e-01  4.61083626e-05 -9.26914428e-01  9.26822211e-01
#   5.04912283e+01 -1.77760025e+00  2.88939575e-04 -1.77788919e+00
#   1.77731131e+00  1.00483703e+02]
# Current V Value:  12757.627716328818
# Outside economic region: False
# Outside stability region: False
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#
#
#
#
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# Iteration # 7191
# Current State Variable Values: x = [-9.26868263e-01  4.61088441e-05 -9.26914372e-01  9.26822154e-01
#   5.04984614e+01 -1.77760001e+00  2.88939894e-04 -1.77788895e+00
#   1.77731107e+00  1.00507058e+02]
# Current V Value:  12760.15587636951
# Outside economic region: False
# Outside stability region: False
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#
#
#
#
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# Iteration # 7192
# Current State Variable Values: x = [-9.26868500e-01  4.61093421e-05 -9.26914609e-01  9.26822391e-01
#   5.05057099e+01 -1.77759959e+00  2.88940171e-04 -1.77788853e+00
#   1.77731065e+00  1.00479202e+02]
# Current V Value:  12757.538506512721
# Outside economic region: False
# Outside stability region: False
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#
#
#
#
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# Iteration # 7193
# Current State Variable Values: x = [-9.26868705e-01  4.61098380e-05 -9.26914814e-01  9.26822595e-01
#   5.04967335e+01 -1.77759895e+00  2.88940395e-04 -1.77788789e+00
#   1.77731001e+00  1.00502538e+02]
# Current V Value:  12759.654482139305
# Outside economic region: False
# Outside stability region: False
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#
#
#
#
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# Iteration # 7194
# Current State Variable Values: x = [-9.26868871e-01  4.61103314e-05 -9.26914981e-01  9.26822760e-01
#   5.05039783e+01 -1.77759813e+00  2.88940578e-04 -1.77788707e+00
#   1.77730919e+00  1.00474657e+02]
# Current V Value:  12757.032215293075
# Outside economic region: False
# Outside stability region: False
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#
#
#
#
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# Iteration # 7195
# Current State Variable Values: x = [-9.26869005e-01  4.61108227e-05 -9.26915116e-01  9.26822894e-01
#   5.04949981e+01 -1.77759708e+00  2.88940709e-04 -1.77788603e+00
#   1.77730814e+00  1.00497969e+02]
# Current V Value:  12759.143102079248
# Outside economic region: False
# Outside stability region: False
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#
#
#
#
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# Iteration # 7196
# Current State Variable Values: x = [-9.26869100e-01  4.61113115e-05 -9.26915212e-01  9.26822989e-01
#   5.05022392e+01 -1.77759819e+00  2.88941335e-04 -1.77788713e+00
#   1.77730925e+00  1.00521404e+02]
# Current V Value:  12761.687740969342
# Outside economic region: False
# Outside stability region: False
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#
#
#
#
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# Iteration # 7197
# Current State Variable Values: x = [-9.26869164e-01  4.61117982e-05 -9.26915275e-01  9.26823052e-01
#   5.04932554e+01 -1.77759911e+00  2.88941919e-04 -1.77788805e+00
#   1.77731017e+00  1.00493622e+02]
# Current V Value:  12758.673813674126
# Outside economic region: False
# Outside stability region: False
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#
#
#
#
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# Iteration # 7198
# Current State Variable Values: x = [-9.26869188e-01  4.61122824e-05 -9.26915301e-01  9.26823076e-01
#   5.05004927e+01 -1.77759980e+00  2.88942449e-04 -1.77788874e+00
#   1.77731085e+00  1.00517031e+02]
# Current V Value:  12761.213101337233
# Outside economic region: False
# Outside stability region: False
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#
#
#
#
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# Iteration # 7199
# Current State Variable Values: x = [-9.26869181e-01  4.61127644e-05 -9.26915294e-01  9.26823068e-01
#   5.04915051e+01 -1.77760029e+00  2.88942936e-04 -1.77788924e+00
#   1.77731135e+00  1.00489224e+02]
# Current V Value:  12758.19408870248
# Outside economic region: False
# Outside stability region: False
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#
#
#
#
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# Iteration # 7200
# Current State Variable Values: x = [-9.26869135e-01  4.61132440e-05 -9.26915248e-01  9.26823021e-01
#   5.04987388e+01 -1.77760056e+00  2.88943370e-04 -1.77788951e+00
#   1.77731162e+00  1.00512608e+02]
# Current V Value:  12760.72807944325
# Outside economic region: False
# Outside stability region: False
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# Total time required to execute the code = 3695.719884 seconds

# %%
from controllers import *
# %matplotlib widget
plt.rcParams['font.size'] = 15
plt.rcParams['figure.constrained_layout.use'] = True
plt.rcParams['pdf.fonttype'] = 42  # Use TrueType fonts
plt.rcParams['ps.fonttype'] = 42   # Also for PostScript outputs
plt.rcParams['text.usetex'] = False
plt.gcf().align_ylabels()
plt.close('all')
fig = plt.figure(figsize = (10,15))
grid = fig.add_gridspec(7,2,hspace = 0)
axes = grid.subplots(sharex=True,sharey=False)

stateNames = np.array(['C_B_1_record', 'C_DEB_1_record', 'C_E_1_record', 'C_EB_1_record', 'T_1_record', 'C_B_2_record', 'C_DEB_2_record', 'C_E_2_record', 'C_EB_2_record', 'T_2_record']).reshape(2,5)
controlNames = ['Q_1_record', 'Q_2_record']
stateVariableNames = np.array(['C_B1d', 'C_DEB1d', 'C_E1d', 'C_EB1d', 'T_1d', 'C_B2d', 'C_DEB2d', 'C_E2d', 'C_EB2d', 'T_2d']).reshape(2,5)
controlVariableNames = ['Q1d', 'Q2d']
steadystateVariableNames = np.array(['C_B1s', 'C_DEB1s', 'C_E1s', 'C_EB1s', 'T_1s', 'C_B2s', 'C_DEB2s', 'C_E2s', 'C_EB2s', 'T_2s']).reshape(2,5)
steadycontrolVariableNames = ['Q1s', 'Q2s']

#Plotting the results
colors = ['r', 'k', 'b', 'y', 'g','m']
labels = ['C_{B', 'C_{DEB', 'C_{E', 'C_{EB', 'T','Q']

for i in range(6):
        for j in range(2):
            if i<4:
                latex_label = f"${labels[i]}_{{{j+1}}}}}$"
                latex_labels = f"${{{labels[i]}_{{{j+1}_{{s}}}}}}}}$"
            else:
                latex_label = f"${labels[i]}_{{{j+1}}}$"
                latex_labels = f"${{{labels[i]}_{{{j+1}_{{s}}}}}}$"
            if i==5:
                axes[i,j].plot(np.array(np.loadtxt(os.path.join('Results_PIcontrol-encrypted-0', f'{controlNames[j]}.txt'), delimiter = ",")[:np.loadtxt(os.path.join('Results_PIcontrol-encrypted-0', 'finalIteration.txt'), delimiter = ",",dtype=int)])+globals()[steadycontrolVariableNames[j]],colors[i],label=latex_label)
                axes[i,j].axhline(globals()[controlVariableNames[j]]+globals()[steadycontrolVariableNames[j]],color=colors[i],linestyle='--',label=latex_labels)
            else:    
                axes[i,j].plot(np.array(np.loadtxt(os.path.join('Results_PIcontrol-encrypted-0', f'{stateNames[j,i]}.txt'), delimiter = ",")[:np.loadtxt(os.path.join('Results_PIcontrol-encrypted-0', 'finalIteration.txt'), delimiter = ",",dtype=int)])+globals()[steadystateVariableNames[j,i]],colors[i],label=latex_label)
                axes[i,j].axhline(globals()[stateVariableNames[j,i]]+globals()[steadystateVariableNames[j,i]],color=colors[i],linestyle='--',label=latex_labels)
            axes[i,j].set_xlabel('Time [s]')
            axes[i,j].set_ylabel(latex_label)
            axes[i,j].legend()
for ax in axes[-1,:]:
    ax.remove()
cost_axis = fig.add_subplot(grid[-1, :])  # Span across both columns
cost_axis.plot(np.loadtxt(os.path.join('Results_PIcontrol-encrypted-0', 'costRecord.txt'), delimiter = ","), 'c', label='Cost')
cost_axis.set_xlabel('Time [s]')
cost_axis.set_ylabel('Cost')
# Adjust tick marks for cost_axis only
cost_axis.locator_params(axis='x', nbins=5)  # Fewer ticks on x-axis
cost_axis.locator_params(axis='y', nbins=5)  # Fewer ticks on y-axis
cost_axis.legend()
# Adjust the layout so plots do not overlap
#plt.tight_layout()
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
