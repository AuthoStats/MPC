# %%
from controllers import *
#open(os.path.join('Aspen Stuff', 'stop.txt'), 'w').close()

# %%
wipeFolder('Aspen Stuff')
# %matplotlib widget
#p1,p2,p3,p4,p5,p6,p7,p8,p9,p10 = [200,200,400,1000,2.5 ,250,250  ,200,1000  ,0.5]
#p1,p2,p3,p4,p5,p6,p7,p8,p9,p10 = 1e4*np.array([0.6357972255156994,96707.55554749382,1.0790583979938957,60.86066360843278,0.0002578547214190546 ,17.5124842176659,101949.56051420174  ,104.37657105590257,3.128718017349537  ,0.000010846300887665446])
# p1,p2,p3,p4,p5,p6,p7,p8,p9,p10 = 1e4*np.array([0.0022651943949355755, 99862.1425902443,0.0037207980131110587,0.23169361065482735, 99997.5847989014,0.12560566345806118,58.34210398144645,2.3147505112012268,5.8635314442677045,98975.1811344455])
# p1,p2,p3,p4,p5,p6,p7,p8,p9,p10 = 1e6*np.array([0.0009702344234737915,1.1216300873784233,0.0015283028135708204,1.1220321466763308,0.0000003056064046823101,0.0012133090221050846,1.1216300873784233,0.0019023081463311001,1.1216838484014913,0.00000022497017009016127])

# P matrix values: P is a Positive definite 10x10 real matrix 
P1 = 200
P2= 250
P3= 2500
P4=10
P5=0.25
P6=1000
P7=1000
P8=500
P9=1
P10=0.5

# k_1,k_2,k_3 = 1500898.8475089157, 51911.41903311291, 4.166999999999997
# #E_1,E_2,E_3 = 7.94305039e+04,7.96897538e+04,1.24494237e+05
# Cp1,Cp2 = 1.8097737040262707, 2.6356562630366525
# Out:
# File does not exist: c:\Users\arthu\JupyterNotebook\Code\MPC\Aspen\Aspen Stuff\greenLightAspen
# File does not exist: c:\Users\arthu\JupyterNotebook\Code\MPC\Aspen\Aspen Stuff\greenLightPython
# File does not exist: c:\Users\arthu\JupyterNotebook\Code\MPC\Aspen\Aspen Stuff\u.txt
# File does not exist: c:\Users\arthu\JupyterNotebook\Code\MPC\Aspen\Aspen Stuff\dynamicValues.txt
# File deletion process completed.

# %%
from controllers import *
# %matplotlib widget
# controlStepSize = 100
# hcMPC = 0.3
#Process time is 6hr
#Sampling time is 30 seconds
#Integration timestep is 0.3s


netSteps = netPIControlTimeSteps
targetTemps = np.array([50.0,100.0])
Kc=np.array([500.0, 1500.0])
Ki=np.array([0.1, 0.1])

# Initial Values
initialValues = np.loadtxt(os.path.join('Aspen Stuff', 'initialValues.txt'), delimiter=",")
C_B1_i   = initialValues[0,0] - C_B1s    # kmol/m3
C_DEB1_i = initialValues[0,1] - C_DEB1s  # kmol/m3
C_E1_i   = initialValues[0,2] - C_E1s    # kmol/m3
C_EB1_i  = initialValues[0,3] - C_EB1s   # kmol/m3
T_1_i    = initialValues[0,4] - T_1s     # K
C_B2_i   = initialValues[1,0] - C_B2s    # kmol/m3
C_DEB2_i = initialValues[1,1] - C_DEB2s  # kmol/m3
C_E2_i   = initialValues[1,2] - C_E2s    # kmol/m3
C_EB2_i  = initialValues[1,3] - C_EB2s   # kmol/m3
T_2_i    = initialValues[1,4] - T_2s     # K

# Initialize the state, control, and error Records
stateRecord = np.zeros((2,5,netSteps+1))
stateRecord[0,0,0] = C_B1_i 
stateRecord[0,1,0] = C_DEB1_i
stateRecord[0,2,0] = C_E1_i
stateRecord[0,3,0] = C_EB1_i
stateRecord[0,4,0] = T_1_i
stateRecord[1,0,0] = C_B2_i
stateRecord[1,1,0] = C_DEB2_i
stateRecord[1,2,0] = C_E2_i
stateRecord[1,3,0] = C_EB2_i
stateRecord[1,4,0] = T_2_i

#Steady State Values of state variables
Q1d     = Q_(-306.00127008393844 ,'kJ/s').magnitude                - Q1s
Q2d     = Q_(-519.6721950335846 ,'kJ/s').magnitude              - Q2s
C_B1d   = Q_(5.7227369200741904 ,'kmol/m^3').magnitude      - C_B1s    # kmol/m3
C_DEB1d = Q_(3.7847819651713003e-05 ,'kmol/m^3').magnitude - C_DEB1s  # kmol/m3
C_E1d   = Q_(9.4830667871228003e-01 ,'kmol/m^3').magnitude      - C_E1s    # kmol/m3
C_EB1d  = Q_(9.6137458085552596e-01 ,'kmol/m^3').magnitude     - C_EB1s   # kmol/m3
T_1d    = Q_(3.5021535778966199e+02 ,'K').magnitude             - T_1s     # K
C_B2d   = Q_(4.2242089099114501 ,'kmol/m^3').magnitude      - C_B2s    # kmol/m3
C_DEB2d = Q_(2.1677362152708099e-04 ,'kmol/m^3').magnitude - C_DEB2s  # kmol/m3
C_E2d   = Q_(1.6699014297496406e-01 ,'kmol/m^3').magnitude       - C_E2s    # kmol/m3
C_EB2d  = Q_(1.6460876946348100 ,'kmol/m^3').magnitude      - C_EB2s   # kmol/m3
T_2d    = Q_(4.0050873892022503e+02 ,'K').magnitude             - T_2s     # K

controlRecord = np.zeros((2,netSteps))
costRecord = np.zeros((netSteps))
errorRecord = [[] for _ in controlRecord]

###########Q Matrices for Cost Function##############
# Qx=np.diag(np.tile([2e3, 1], int(NUM_OUTPUTS/2)))
# Qu=np.diag(np.tile([8e-13, 0.001], int(NUM_OUTPUTS/2)))
loopsPerHour = int(((1.0*60*60)/hcPI)/controlStepSize)
A1 = np.repeat(10*np.ones(6),loopsPerHour)
A2 = np.repeat(10*np.ones(6),loopsPerHour)
A3 = np.repeat(1e-8*np.ones(6),loopsPerHour)
A4 = 0.08
A5 = 0.1
# A1 = np.repeat(10*np.array([1, 0.9, 1.1, 0.8, 1.2, 0.7]),loopsPerHour)
# A2 = np.repeat(1e-8*np.array([1, 0.8 , 1.2, 0.6 , 1.4,0.5]),loopsPerHour)

# Storing the steady state values in 2 arrays
x_ss = np.array([[ C_B1s,C_DEB1s, C_E1s,C_EB1s,  T_1s], [ C_B2s,C_DEB2s,C_E2s, C_EB2s,  T_2s]])
print(f"The steady state values are {x_ss}")

# Transfer the initial values into realtime array, wont store the data permanently, created record lists for that.
currentState = np.array([[ C_B1_i,C_DEB1_i,C_E1_i, C_EB1_i,  T_1_i], [ C_B2_i, C_DEB2_i,C_E2_i, C_EB2_i, T_2_i]])
print(f"The initial values are {currentState}")
# Out:
# The steady state values are [[6.95758474e+00 3.10286075e-08 1.95760263e+00 4.23901308e-02
#   3.00000000e+02]
#  [6.43501782e+00 2.81861916e-08 1.96109384e+00 3.87321918e-02
#   3.00000000e+02]]
# The initial values are [[ 4.44089210e-15 -2.64697796e-23  1.99840144e-15  1.38777878e-17
#    2.84217094e-13]
#  [ 2.66453526e-15 -1.98523347e-23 -3.99680289e-15  4.16333634e-17
#    1.70530257e-13]]

# %%
###################### MPC Cost Weight Matrix #####################
q1 =5
q2 =5
q3=650
q4=5
q5=2.5
q6=25
q7=25
q8=100
q9=2
q10=6

r1 = 5*1e-6
r2 = 1.25*1e-5
#Transfer the initial values into realtime array, wont store the data permanently, created record lists for that. 
#realtime_data1 = np.array([CE1_i, CB1_i, CEB1_i, CDEB1_i, T1_i])
#realtime_data2 = np.array([CE2_i, CB2_i, CEB2_i, CDEB2_i, T2_i])
Cp = Cp1
Coeff1 = F1/V1
Coeff2 = F1/V2
Coeff3 = F2_new/V2
@njit
def model_makestep(x,u, steps=100, hc=1e-4):
    C_B1,C_DEB1,C_E1,C_EB1,T_1,C_B2,C_DEB2,C_E2,C_EB2,T_2 = x
    Q1,Q2 = u
    for _ in range(steps):
        r1_1  = k_1*math.exp(-E_1/R/(T_1+T_1s))*((C_B1+C_B1s)*(C_E1+C_E1s))
        r1s_1 = k_1*math.exp(-E_1/R/T_1s)*(C_B1s*C_E1s)
        r2_1  = k_2*math.exp(-E_2/R/(T_1+T_1s))*((C_EB1+C_EB1s)*(C_E1+C_E1s))
        r2s_1 = k_2*math.exp(-E_2/R/T_1s)*(C_EB1s*C_E1s)
        r3_1  = k_3*math.exp(-E_3/R/(T_1+T_1s))*((C_B1+C_B1s)*(C_DEB1+C_DEB1s))
        r3s_1 = k_3*math.exp(-E_3/R/T_1s)*(C_B1s*C_DEB1s) 
        r1_2  = k_1*math.exp(-E_1/R/(T_2+T_2s))*((C_B2+C_B2s)*(C_E2+C_E2s))
        r1s_2 = k_1*math.exp(-E_1/R/T_2s)*(C_B2s*C_E2s)
        r2_2  = k_2*math.exp(-E_2/R/(T_2+T_2s))*((C_EB2+C_EB2s)*(C_E2+C_E2s))
        r2s_2 = k_2*math.exp(-E_2/R/T_2s)*(C_EB2s*C_E2s)
        r3_2  = k_3*math.exp(-E_3/R/(T_2+T_2s))*((C_B2+C_B2s)*(C_DEB2+C_DEB2s))
        r3s_2 = k_3*math.exp(-E_3/R/T_2s)*(C_B2s*C_DEB2s)

        C_B1   = max(-C_B1s,C_B1+hc*(Coeff1*(-C_B1)                            - r1_1 + r1s_1  - r3_1 + r3s_1))
        C_B2   = max(-C_B2s,C_B2+hc*(Coeff2*(C_B1-C_B2)     + Coeff3*(-C_B2)   - r1_2 + r1s_2  - r3_2 + r3s_2))
        C_DEB1 = max(-C_DEB1s,C_DEB1+hc*(Coeff1*(-C_DEB1)                          + r2_1 - r2s_1 - r3_1 + r3s_1))
        C_DEB2 = max(-C_DEB2s,C_DEB2+hc*(Coeff2*(C_DEB1-C_DEB2) + Coeff3*(-C_DEB2) + r2_2 - r2s_2 - r3_2 + r3s_2))
        C_E1   = max(-C_E1s,C_E1+hc*(Coeff1*(-C_E1)                            - r1_1 + r1s_1  - r2_1 + r2s_1))
        C_E2   = max(-C_E2s,C_E2+hc*(Coeff2*(C_E1-C_E2)     + Coeff3*(-C_E2)   - r1_2 + r1s_2  - r2_2 + r2s_2))
        C_EB1  = max(-C_EB1s,C_EB1+hc*(Coeff1*(-C_EB1)                           + r1_1 - r1s_1  - r2_1 + r2s_1 + 2*(r3_1-r3s_1)))
        C_EB2  = max(-C_EB2s,C_EB2+hc*(Coeff2*(C_EB1-C_EB2)   + Coeff3*(-C_EB2)  + r1_2 - r1s_2  - r2_2 + r2s_2 + 2*(r3_2-r3s_2)))
        T_1    = max(-T_1s,T_1+hc*(Coeff1*(-T_1)                    - H_1*(r1_1-r1s_1)/(rhoe_L1*Cp1) - H_2*(r2_1-r2s_1)/(rhoe_L1*Cp1)- H_3*(r3_1-r3s_1)/(rhoe_L1*Cp1) +Q1/(rhoe_L1 * Cp1 * V1)))
        T_2    = max(-T_2s,T_2+hc*(Coeff2*(T_1-T_2) + Coeff3*(-T_2) - H_1*(r1_2-r1s_2)/(rhoe_L2*Cp2) - H_2*(r2_2-r2s_2)/(rhoe_L2*Cp2)- H_3*(r3_2-r3s_2)/(rhoe_L2*Cp2) +Q2/(rhoe_L2 * Cp2 * V2)))
    return np.array([C_B1,C_DEB1,C_E1,C_EB1,T_1,C_B2,C_DEB2,C_E2,C_EB2,T_2])
def eval_f(u):
    offset=0
    x = stateRecord[:,:,main_iteration].reshape(-1)
    ### check how to write the inputs 
    for controlIteration in range(controlTimeStepsPerMPC):
        Q1    = u.item(NUM_U*controlIteration + 0)  # Heat input for reactor 1
        Q2    = u.item(NUM_U*controlIteration + 1)  # Heat input for reactor 2
        
        # Update states for both reactors
        x = model_makestep(x, [Q1,Q2], controlStepSize, hcMPC)
        x1,x2,x3,x4,x5,x6,x7,x8,x9,x10 = x
        
        offset += q1*((C_B1d-x1)**2.0) + q2*((C_DEB1d-x2)**2.0) + q3*((C_E1d-x3)**2.0) + q4*((C_EB1d-x4)**2.0) + q5*((T_1d-x5)**2.0) \
        +q6*((C_B2d-x6)**2.0) + q7*((C_DEB2d-x7)**2.0) + q8*((C_E2d-x8)**2.0) + q9*((C_EB2d-x9)**2.0) + q10*((T_2d-x10)**2.0)
        
        offset= offset +  (Q1d - u[2*controlIteration+0]) **2*r1  + (Q2d - u[2*controlIteration+1]) **2 *r2
        #offset_record.append(offset/10)
        
    return offset*delta
def calcCost(x,u,index):
    val1 =-A1[:index+1]*(x[1,3,1:index+2]+ C_EB2s)
    val2 =-A2[:index+1]*(x[0,3,1:index+2]+ C_EB1s)
    val3 = A3[:index+1]*((u[0,:index+1]+Q1s)**2 + (u[1,:index+1]+Q2s)**2)
    val4 = A4*np.maximum(0,x[0,-1,1:index+2]-(350-T_1s))
    val5 = A5*np.maximum(0,x[1,-1,1:index+2]-(400-T_2s))
    # print(val1)
    # print(val2)
    # print(val3)
    # print(val4)
    # print(val5)
    return sum(val1+val2+val3+val4+val5)
#Computing the gradient of f(x) which represents the cost function and hence its the derivative of the cost function.
def eval_grad_f(x):
    assert len(x) == int(NUM_MPC_INPUTS)
    step = 1.0e-3 # we just have a small step
    objp=objm=0
    grad_f = [0]*NUM_MPC_INPUTS
    xpstep = [0]*NUM_MPC_INPUTS
    xmstep = [0]*NUM_MPC_INPUTS
    for i_mpc_input in range(NUM_MPC_INPUTS):
        xpstep=x.copy()
        xmstep=x.copy()
        # for each variables, we need to evaluate the derivative of the function with respect to that variable, This is why we have the for loop
        xpstep[i_mpc_input]  = xpstep[i_mpc_input]+step 
        xmstep[i_mpc_input] = xmstep[i_mpc_input]-step
        # Evaluate the objective function at xpstep and xmstep
        objp=eval_f(xpstep) # This function returns the value of the objective function evaluated with the variable x[i] is perturebed +step
        objm=eval_f(xmstep) # This function returns the value of the objective function evaluated with the variable x[i] is perturebed -step
        #print ("obj ", objp, "   objm   ", objm)
        grad_f[i_mpc_input] = (objp - objm) / (2 * step) # This evaluates the gradient of the objetive function with repect to the optimization variable x[i]
    #print("Gradient: ", grad_f)
    return np.array(grad_f)



def eval_g(u):  # V condition, Vdot condition, the Energy constraint
    g = np.array([-1.0] * (controlTimeStepsPerMPC))  # Default to <0 i.e invalid
    x = stateRecord[:,:,main_iteration].reshape(-1)
    xss = x_ss.reshape(-1)
    T_1 = x.item(4)
    T_1s = xss.item(4)
    T_2 = x.item(9)
    T_2s = xss.item(9)
    deviationLimit = 0.5
    
    bias =  0
    
    
    # if np.isnan(u).any():
    #     g[:] = -1
    #     return g
    #print(u)
    if (abs(T_1/T_1s)>deviationLimit or abs(T_2/T_2s)>deviationLimit):#Check if any term is 15% off the steady state value, i.e, the system is not in the economic region
        Q1 = u.item(0)
        Q2 = u.item(1)

        LfV = 0.0
        Lg1V = (2 * P5  * T_1 ) /(rhoe_L1 * Cp1 * V1)
        Lg2V = (2 * P10 * T_2 ) /(rhoe_L2 * Cp2 * V2)
        dV_op2 = LfV + Lg1V * Q1 + Lg2V * Q2  # (EMPC)Vdot = LfV(x)+LgV(x)*u
        #print(f"dV_op2 = {dV_op2}")
        u11 = Kc.item(0) * (0.0 - T_1)
        u22 = Kc.item(1) * (0.0 - T_2)
        dV_Pu2 = LfV + Lg1V * u11 + Lg2V * u22  # (PI)Vdot = LfV(x)+LgV(x)*u
        #print(f"dV_Pu2 = {dV_Pu2}")
        g[:] = min(0.0, dV_Pu2 - bias) - dV_op2 # Ensure we perform better than the Reference Controller
    else:
        for controlIteration in range(controlTimeStepsPerMPC):
            #print(f"Before Step {controlIteration}: {x}")
            Q1   = u.item(NUM_U * controlIteration + 0)
            Q2   = u.item(NUM_U * controlIteration + 1)
            x = model_makestep(x,[Q1,Q2],controlStepSize,hcMPC)
            #print(f"After Step {controlIteration}: {x}")
            g[controlIteration] = 2*deviationLimit - abs(x.item(4)/x_ss.item(4)) - abs(x.item(9)/x_ss.item(9))
            # test = 2*deviationLimit - abs(x.item(4)/x_ss.item(4)) - abs(x.item(9)/x_ss.item(9)) # Ensure we stay in the economic region
            # if np.isnan(test):
            #     g[controlIteration] = -1
            # else:
            #     g[controlIteration] = test
    
    #print(x_ss.item(9))
    #print(g)
    return g  # f(x) + C >= 0
cons = [
    #{"type": "eq", "fun": equalityConstraints},
    #{"type": "ineq", "fun": eval_g, "jac": eval_jac_g},
    {"type": "ineq", "fun": eval_g},
]

u_L = []
u_U = []
lowerBounds = [-4e3,-3e4]       # Max cooling = 10 * heat needed to sustain first principles steady state.
upperBounds = [5e3-Q1s,5e3-Q2s] # Max heating = heat needed to raise 60m^3 or water by 80K in 1hr
for _ in range(controlTimeStepsPerMPC):
    u_L = u_L + lowerBounds
    u_U = u_U + upperBounds
bnds = [(u_L[_], u_U[_]) for _ in range(NUM_MPC_INPUTS)]

# %%
def writeInputs(u):
    inputFile = os.path.join('Aspen Stuff', 'u.txt')
    np.savetxt(inputFile, [u.item(0)+Q1s,u.item(1)+Q2s], fmt ='%.5f')
    open(os.path.join('Aspen Stuff', 'greenLightAspen'), 'w').close()
def waitForAspen():
    # Load data from Aspen
    file = os.path.join('Aspen Stuff', 'greenLightPython')
    print(f"Waiting for Aspen to send data...(Iteration #{main_iteration+1})",end='\r')
    while not os.path.isfile(file):
        pass
    print(f"Aspen Data found.",end='\r')
def readAspen():
    file = os.path.join('Aspen Stuff', 'greenLightPython')
    dynamicData = np.loadtxt(os.path.join('Aspen Stuff', 'dynamicValues.txt'), delimiter = ",")
    while os.path.isfile(file):
        try:
            os.remove(file)
        except PermissionError:
            pass
    return dynamicData
def writeResults(stateRecord,controlRecord,costRecord,index):
    stateNames = ['C_B_1_record', 'C_DEB_1_record', 'C_E_1_record', 'C_EB_1_record', 'T_1_record', 'C_B_2_record', 'C_DEB_2_record', 'C_E_2_record', 'C_EB_2_record', 'T_2_record']
    controlNames = ['Q_1_record', 'Q_2_record']
    for i, name in enumerate(stateNames):
        file = os.path.join('Results_PIcontrol-Unencrypted', f'{name}.txt')
        np.savetxt(file, stateRecord[i//5,i%5,:])
    for i, name in enumerate(controlNames):
        file = os.path.join('Results_PIcontrol-Unencrypted', f'{name}.txt')
        np.savetxt(file, controlRecord[i,:])
    file = os.path.join('Results_PIcontrol-Unencrypted', 'costRecord.txt')
    np.savetxt(file, costRecord[:])
    file = os.path.join('Results_PIcontrol-Unencrypted', 'finalIteration.txt')
    np.savetxt(file, [index+1],fmt='%i')

# %%
#Transfer the initial values into realtime array, wont store the data permanently, created record lists for that. 
start_time = time.time()
for main_iteration in range(netPIControlTimeSteps):
    print("\n\n\n")
    print("%%%%%%%%%%%%%%%%%%%%%%%%%%%%%")
    print("Iteration #", main_iteration + 1)
    print(f"Current State Variable Values: x = {stateRecord[:,:,main_iteration].reshape(-1)}")
    print("Current V Value: ", np.dot(stateRecord[:,:,main_iteration].reshape(-1),np.dot(np.diag([P1,P2,P3,P4,P5,P6,P7,P8,P9,P10]),stateRecord[:,:,main_iteration].reshape(-1))))
    print("Outside economic region:",np.any(abs(stateRecord[:,-1,main_iteration].reshape(-1)/x_ss[:,-1].reshape(-1))>0.5))
    print("Outside stability region:",np.any(abs(stateRecord[:,-1,main_iteration].reshape(-1)/x_ss[:,-1].reshape(-1))>1))
    print("%%%%%%%%%%%%%%%%%%%%%%%%%%%%%")

    u = solvePI(T=stateRecord[:,-1,main_iteration],
                T_setpoint=targetTemps,
                Kc=Kc,
                Ki=Ki,
                PIcontrolStepSize=PIcontrolStepSize,
                hc=hcPI,
                lowerBounds = lowerBounds,
                upperBounds = upperBounds,
                errorRecord = errorRecord,
                encrypted = False, 
                isArray = True)
    
    # Define the initial values of the Control Variables
    controlRecord[0][main_iteration] =  u.item(0)
    controlRecord[1][main_iteration] =  u.item(1)
    #writeInputs(u)
    #waitForAspen()
    #dynamicData = readAspen()
    stateRecord[:,:,main_iteration+1] = model_makestep(stateRecord[:,:,main_iteration].reshape(-1),u.reshape(-1),PIcontrolStepSize,hcPI).reshape(2,5)
    #stateRecord[:,:,main_iteration+1] = dynamicData - x_ss
    costRecord[main_iteration] = calcCost(stateRecord,controlRecord,main_iteration)
    writeResults(stateRecord,controlRecord,costRecord,main_iteration)

end_time = time.time()

total_runtime = end_time - start_time
print("Total time required to execute the code = %f seconds " % total_runtime)
# Out:
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# Iteration # 1
# Current State Variable Values: x = [ 4.44089210e-15 -2.64697796e-23  1.99840144e-15  1.38777878e-17
#   2.84217094e-13  2.66453526e-15 -1.98523347e-23 -3.99680289e-15
#   4.16333634e-17  1.70530257e-13]
# Current V Value:  6.375041720811883e-26
# Outside economic region: False
# Outside stability region: False
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#
#
#
#
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# Iteration # 2
# Current State Variable Values: x = [-1.56504937e-07  1.70099297e-13 -1.56505110e-07  1.56504771e-07
#   1.64026389e-01 -1.52588408e-07  1.63845190e-13 -1.52588579e-07
#   1.52588247e-07  1.72555717e-01]
# Current V Value:  0.021613901842758545
# Outside economic region: False
# Outside stability region: False
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#
#
#
#
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# Iteration # 3
# Current State Variable Values: x = [-6.32038471e-07  6.87638395e-13 -6.32039161e-07  6.32037788e-07
#   3.27975929e-01 -6.16348592e-07  6.62525566e-13 -6.16349261e-07
#   6.16347932e-07  3.45013715e-01]
# Current V Value:  0.08640928588445507
# Outside economic region: False
# Outside stability region: False
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#
#
#
#
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# Iteration # 4
# Current State Variable Values: x = [-1.43094821e-06  1.55842446e-12 -1.43094978e-06  1.43094666e-06
#   4.91848972e-01 -1.39571393e-06  1.50189675e-12 -1.39571544e-06
#   1.39571243e-06  5.17374402e-01]
# Current V Value:  0.1943169970102746
# Outside economic region: False
# Outside stability region: False
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#
#
#
#
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# Iteration # 5
# Current State Variable Values: x = [-2.55763657e-06  2.78836121e-12 -2.55763936e-06  2.55763379e-06
#   6.55645873e-01 -2.49517573e-06  2.68791543e-12 -2.49517843e-06
#   2.49517305e-06  6.89638188e-01]
# Current V Value:  0.3452683199034513
# Outside economic region: False
# Outside stability region: False
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#
#
#
#
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# Iteration # 6
# Current State Variable Values: x = [-4.01656134e-06  4.38345054e-12 -4.01656572e-06  4.01655696e-06
#   8.19366994e-01 -3.91928388e-06  4.22664114e-12 -3.91928811e-06
#   3.91927965e-06  8.61805487e-01]
# Current V Value:  0.5391949836575308
# Outside economic region: False
# Outside stability region: False
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#
#
#
#
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# Iteration # 7
# Current State Variable Values: x = [-5.81223634e-06  6.34979420e-12 -5.81224269e-06  5.81223000e-06
#   9.83012697e-01 -5.67264750e-06  6.12423807e-12 -5.67265363e-06
#   5.67264138e-06  1.03387672e+00]
# Current V Value:  0.7760291664568485
# Outside economic region: False
# Outside stability region: False
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#
#
#
#
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# Iteration # 8
# Current State Variable Values: x = [-7.94923205e-06  8.69359551e-12 -7.94924075e-06  7.94922336e-06
#   1.14658335e+00 -7.75993566e-06  8.38697690e-12 -7.75994406e-06
#   7.75992728e-06  1.20585231e+00]
# Current V Value:  1.0557035003261646
# Outside economic region: False
# Outside stability region: False
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#
#
#
#
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# Iteration # 9
# Current State Variable Values: x = [-1.04321762e-05  1.14211611e-11 -1.04321876e-05  1.04321648e-05
#   1.31007932e+00 -1.01858781e-05  1.10212367e-11 -1.01858891e-05
#   1.01858670e-05  1.37773268e+00]
# Current V Value:  1.3781510759503934
# Outside economic region: False
# Outside stability region: False
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#
#
#
#
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# Iteration # 10
# Current State Variable Values: x = [-1.32657545e-05  1.45389026e-11 -1.32657691e-05  1.32657400e-05
#   1.47350099e+00 -1.29552657e-05  1.40335067e-11 -1.29552797e-05
#   1.29552516e-05  1.54951826e+00]
# Current V Value:  1.7433054475654073
# Outside economic region: False
# Outside stability region: False
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#
#
#
#
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# Iteration # 11
# Current State Variable Values: x = [-1.64547112e-05  1.80533386e-11 -1.64547292e-05  1.64546931e-05
#   1.63684874e+00 -1.60729515e-05  1.74303886e-11 -1.60729690e-05
#   1.60729341e-05  1.72120950e+00]
# Current V Value:  2.151100637920881
# Outside economic region: False
# Outside stability region: False
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#
#
#
#
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# Iteration # 12
# Current State Variable Values: x = [-2.00038497e-05  2.19710964e-11 -2.00038716e-05  2.00038277e-05
#   1.80012294e+00 -1.95438514e-05  2.12185982e-11 -1.95438726e-05
#   1.95438301e-05  1.89280682e+00]
# Current V Value:  2.6014711433161866
# Outside economic region: False
# Outside stability region: False
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#
#
#
#
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# Iteration # 13
# Current State Variable Values: x = [-2.39180333e-05  2.62989138e-11 -2.39180596e-05  2.39180070e-05
#   1.96332399e+00 -2.33729443e-05  2.54049674e-11 -2.33729697e-05
#   2.33729189e-05  2.06431068e+00]
# Current V Value:  3.0943519387103393
# Outside economic region: False
# Outside stability region: False
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#
#
#
#
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# Iteration # 14
# Current State Variable Values: x = [-2.82021861e-05  3.10436411e-11 -2.82022171e-05  2.82021550e-05
#   2.12645227e+00 -2.75652737e-05  2.99964469e-11 -2.75653037e-05
#   2.75652437e-05  2.23572153e+00]
# Current V Value:  3.629678482907046
# Outside economic region: False
# Outside stability region: False
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#
#
#
#
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# Iteration # 15
# Current State Variable Values: x = [-3.28612930e-05  3.62122433e-11 -3.28613292e-05  3.28612568e-05
#   2.28950818e+00 -3.21259478e-05  3.50001073e-11 -3.21259828e-05
#   3.21259128e-05  2.40703981e+00]
# Current V Value:  4.207386723815883
# Outside economic region: False
# Outside stability region: False
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#
#
#
#
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# Iteration # 16
# Current State Variable Values: x = [-3.79004012e-05  4.18118015e-11 -3.79004430e-05  3.79003594e-05
#   2.45249213e+00 -3.70601404e-05  4.04231421e-11 -3.70601809e-05
#   3.70601000e-05  2.57826598e+00]
# Current V Value:  4.82741310379069
# Outside economic region: False
# Outside stability region: False
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#
#
#
#
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# Iteration # 17
# Current State Variable Values: x = [-4.33246203e-05  4.78495153e-11 -4.33246681e-05  4.33245724e-05
#   2.61540450e+00 -4.23730918e-05  4.62728698e-11 -4.23731381e-05
#   4.23730456e-05  2.74940052e+00]
# Current V Value:  5.489694565046268
# Outside economic region: False
# Outside stability region: False
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#
#
#
#
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# Iteration # 18
# Current State Variable Values: x = [-4.91391231e-05  5.43327051e-11 -4.91391774e-05  4.91390688e-05
#   2.77824572e+00 -4.80701094e-05  5.25567354e-11 -4.80701619e-05
#   4.80700568e-05  2.92044388e+00]
# Current V Value:  6.194168555154454
# Outside economic region: False
# Outside stability region: False
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#
#
#
#
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# Iteration # 19
# Current State Variable Values: x = [-5.53491467e-05  6.12688137e-11 -5.53492079e-05  5.53490854e-05
#   2.94101619e+00 -5.41565683e-05  5.92823139e-11 -5.41566276e-05
#   5.41565090e-05  3.09139653e+00]
# Current V Value:  6.940773032620731
# Outside economic region: False
# Outside stability region: False
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#
#
#
#
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# Iteration # 20
# Current State Variable Values: x = [-6.19599926e-05  6.86654087e-11 -6.19600613e-05  6.19599240e-05
#   3.10371633e+00 -6.06379126e-05  6.64573115e-11 -6.06379791e-05
#   6.06378462e-05  3.26225897e+00]
# Current V Value:  7.72944647254252
# Outside economic region: False
# Outside stability region: False
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#
#
#
#
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# Iteration # 21
# Current State Variable Values: x = [-6.89770280e-05  7.65301847e-11 -6.89771046e-05  6.89769515e-05
#   3.26634656e+00 -6.75196557e-05  7.40895686e-11 -6.75197297e-05
#   6.75195816e-05  3.43303165e+00]
# Current V Value:  8.560127872350309
# Outside economic region: False
# Outside stability region: False
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#
#
#
#
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# Iteration # 22
# Current State Variable Values: x = [-7.64056861e-05  8.48709655e-11 -7.64057710e-05  7.64056013e-05
#   3.42890731e+00 -7.48073811e-05  8.21870623e-11 -7.48074633e-05
#   7.48072989e-05  3.60371509e+00]
# Current V Value:  9.432756757632733
# Outside economic region: False
# Outside stability region: False
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#
#
#
#
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# Iteration # 23
# Current State Variable Values: x = [-8.42514671e-05  9.36957065e-11 -8.42515608e-05  8.42513734e-05
#   3.59139900e+00 -8.25067436e-05  9.07579084e-11 -8.25068344e-05
#   8.25066528e-05  3.77430975e+00]
# Current V Value:  10.347273188046994
# Outside economic region: False
# Outside stability region: False
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#
#
#
#
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# Iteration # 24
# Current State Variable Values: x = [-9.25199387e-05  1.03012497e-10 -9.25200417e-05  9.25198357e-05
#   3.75382206e+00 -9.06234697e-05  9.98103644e-11 -9.06235695e-05
#   9.06233699e-05  3.94481615e+00]
# Current V Value:  11.303617763315627
# Outside economic region: False
# Outside stability region: False
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#
#
#
#
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# Iteration # 25
# Current State Variable Values: x = [-1.01216737e-04  1.12829561e-10 -1.01216850e-04  1.01216624e-04
#   3.91617695e+00 -9.91633586e-05  1.09352832e-10 -9.91634680e-05
#   9.91632493e-05  4.11523478e+00]
# Current V Value:  12.301731629311032
# Outside economic region: False
# Outside stability region: False
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#
#
#
#
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# Iteration # 26
# Current State Variable Values: x = [-1.10347568e-04  1.23155264e-10 -1.10347691e-04  1.10347444e-04
#   4.07846409e+00 -1.08132283e-04  1.19393859e-10 -1.08132402e-04
#   1.08132164e-04  4.28556615e+00]
# Current V Value:  13.34155648422896
# Outside economic region: False
# Outside stability region: False
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#
#
#
#
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# Iteration # 27
# Current State Variable Values: x = [-1.19918206e-04  1.33998111e-10 -1.19918340e-04  1.19918072e-04
#   4.24068394e+00 -1.17536190e-04  1.29942144e-10 -1.17536320e-04
#   1.17536060e-04  4.45581077e+00]
# Current V Value:  14.423034584852235
# Outside economic region: False
# Outside stability region: False
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#
#
#
#
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# Iteration # 28
# Current State Variable Values: x = [-1.29934497e-04  1.45366749e-10 -1.29934642e-04  1.29934351e-04
#   4.40283696e+00 -1.27381101e-04  1.41006537e-10 -1.27381242e-04
#   1.27380960e-04  4.62596916e+00]
# Current V Value:  15.54610875290614
# Outside economic region: False
# Outside stability region: False
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#
#
#
#
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# Iteration # 29
# Current State Variable Values: x = [-1.40402359e-04  1.57269973e-10 -1.40402516e-04  1.40402202e-04
#   4.56492359e+00 -1.37673116e-04  1.52596042e-10 -1.37673269e-04
#   1.37672963e-04  4.79604184e+00]
# Current V Value:  16.710722381506695
# Outside economic region: False
# Outside stability region: False
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#
#
#
#
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# Iteration # 30
# Current State Variable Values: x = [-1.51327782e-04  1.69716728e-10 -1.51327951e-04  1.51327612e-04
#   4.72694430e+00 -1.48418408e-04  1.64719823e-10 -1.48418573e-04
#   1.48418244e-04  4.96602934e+00]
# Current V Value:  17.916819441703147
# Outside economic region: False
# Outside stability region: False
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#
#
#
#
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# Iteration # 31
# Current State Variable Values: x = [-1.62716828e-04  1.82716108e-10 -1.62717010e-04  1.62716645e-04
#   4.88889957e+00 -1.59623231e-04  1.77387204e-10 -1.59623409e-04
#   1.59623054e-04  5.13593219e+00]
# Current V Value:  19.164344489116335
# Outside economic region: False
# Outside stability region: False
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#
#
#
#
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# Iteration # 32
# Current State Variable Values: x = [-1.74575634e-04  1.96277361e-10 -1.74575830e-04  1.74575437e-04
#   5.05078985e+00 -1.71293917e-04  1.90607671e-10 -1.71294107e-04
#   1.71293726e-04  5.30575094e+00]
# Current V Value:  20.45324267067403
# Outside economic region: False
# Outside stability region: False
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#
#
#
#
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# Iteration # 33
# Current State Variable Values: x = [-1.86910411e-04  2.10409895e-10 -1.86910622e-04  1.86910201e-04
#   5.21261563e+00 -1.83436875e-04  2.04390880e-10 -1.83437080e-04
#   1.83436671e-04  5.47548612e+00]
# Current V Value:  21.783459731444918
# Outside economic region: False
# Outside stability region: False
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#
#
#
#
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# Iteration # 34
# Current State Variable Values: x = [-1.99727447e-04  2.25123274e-10 -1.99727672e-04  1.99727222e-04
#   5.37437739e+00 -1.96058599e-04  2.18746654e-10 -1.96058817e-04
#   1.96058380e-04  5.64513829e+00]
# Current V Value:  23.15494202157246
# Outside economic region: False
# Outside stability region: False
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#
#
#
#
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# Iteration # 35
# Current State Variable Values: x = [-2.13033105e-04  2.40427229e-10 -2.13033346e-04  2.13032865e-04
#   5.53607561e+00 -2.09165659e-04  2.33684993e-10 -2.09165893e-04
#   2.09165425e-04  5.81470800e+00]
# Current V Value:  24.56763650331045
# Outside economic region: False
# Outside stability region: False
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#
#
#
#
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# Iteration # 36
# Current State Variable Values: x = [-2.26833826e-04  2.56331651e-10 -2.26834082e-04  2.26833569e-04
#   5.69771080e+00 -2.22764712e-04  2.49216068e-10 -2.22764961e-04
#   2.22764463e-04  5.98419581e+00]
# Current V Value:  26.021490758161526
# Outside economic region: False
# Outside stability region: False
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#
#
#
#
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# Iteration # 37
# Current State Variable Values: x = [-2.41136127e-04  2.72846606e-10 -2.41136400e-04  2.41135854e-04
#   5.85928344e+00 -2.36862496e-04  2.65350236e-10 -2.36862761e-04
#   2.36862231e-04  6.15360229e+00]
# Current V Value:  27.516452994120414
# Outside economic region: False
# Outside stability region: False
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#
#
#
#
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# Iteration # 38
# Current State Variable Values: x = [-2.55946608e-04  2.89982327e-10 -2.55946898e-04  2.55946318e-04
#   6.02079405e+00 -2.51465833e-04  2.82098032e-10 -2.51466115e-04
#   2.51465551e-04  6.32292802e+00]
# Current V Value:  29.052472053023216
# Outside economic region: False
# Outside stability region: False
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#
#
#
#
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# Iteration # 39
# Current State Variable Values: x = [-2.71271944e-04  3.07749224e-10 -2.71272252e-04  2.71271637e-04
#   6.18224312e+00 -2.66581630e-04  2.99470181e-10 -2.66581929e-04
#   2.66581331e-04  6.49217357e+00]
# Current V Value:  30.629497418004686
# Outside economic region: False
# Outside stability region: False
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#
#
#
#
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# Iteration # 40
# Current State Variable Values: x = [-2.87118896e-04  3.26157886e-10 -2.87119222e-04  2.87118570e-04
#   6.34363117e+00 -2.82216881e-04  3.17477596e-10 -2.82217199e-04
#   2.82216564e-04  6.66133953e+00]
# Current V Value:  32.24747922106472
# Outside economic region: False
# Outside stability region: False
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#
#
#
#
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# Iteration # 41
# Current State Variable Values: x = [-3.03494302e-04  3.45219081e-10 -3.03494647e-04  3.03493957e-04
#   6.50495873e+00 -2.98378667e-04  3.36131385e-10 -2.98379003e-04
#   2.98378331e-04  6.83042648e+00]
# Current V Value:  33.90636825074625
# Outside economic region: False
# Outside stability region: False
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#
#
#
#
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# Iteration # 42
# Current State Variable Values: x = [-3.20405085e-04  3.64943763e-10 -3.20405450e-04  3.20404720e-04
#   6.66622632e+00 -3.15074156e-04  3.55442853e-10 -3.15074511e-04
#   3.15073801e-04  6.99943504e+00]
# Current V Value:  35.606115959925916
# Outside economic region: False
# Outside stability region: False
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#
#
#
#
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# Iteration # 43
# Current State Variable Values: x = [-3.37858250e-04  3.85343074e-10 -3.37858636e-04  3.37857865e-04
#   6.82743446e+00 -3.32310606e-04  3.75423508e-10 -3.32310981e-04
#   3.32310230e-04  7.16836579e+00]
# Current V Value:  37.34667447371922
# Outside economic region: False
# Outside stability region: False
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#
#
#
#
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# Iteration # 44
# Current State Variable Values: x = [-3.55860889e-04  4.06428350e-10 -3.55861296e-04  3.55860483e-04
#   6.98858370e+00 -3.50095364e-04  3.96085060e-10 -3.50095760e-04
#   3.50094968e-04  7.33721935e+00]
# Current V Value:  39.12799659750228
# Outside economic region: False
# Outside stability region: False
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#
#
#
#
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# Iteration # 45
# Current State Variable Values: x = [-3.74420177e-04  4.28211119e-10 -3.74420605e-04  3.74419749e-04
#   7.14967457e+00 -3.68435869e-04  4.17439432e-10 -3.68436286e-04
#   3.68435451e-04  7.50599634e+00]
# Current V Value:  40.95003582505167
# Outside economic region: False
# Outside stability region: False
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#
#
#
#
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# Iteration # 46
# Current State Variable Values: x = [-3.93543375e-04  4.50703109e-10 -3.93543826e-04  3.93542924e-04
#   7.31070762e+00 -3.87339652e-04  4.39498756e-10 -3.87340091e-04
#   3.87339212e-04  7.67469738e+00]
# Current V Value:  42.81274634680413
# Outside economic region: False
# Outside stability region: False
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#
#
#
#
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# Iteration # 47
# Current State Variable Values: x = [-4.13237833e-04  4.73916251e-10 -4.13238307e-04  4.13237359e-04
#   7.47168341e+00 -4.06814336e-04  4.62275384e-10 -4.06814799e-04
#   4.06813874e-04  7.84332310e+00]
# Current V Value:  44.71608305823845
# Outside economic region: False
# Outside stability region: False
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#
#
#
#
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# Iteration # 48
# Current State Variable Values: x = [-4.33510988e-04  4.97862684e-10 -4.33511486e-04  4.33510490e-04
#   7.63260250e+00 -4.26867641e-04  4.85781890e-10 -4.26868127e-04
#   4.26867155e-04  8.01187413e+00]
# Current V Value:  46.66000156838129
# Outside economic region: False
# Outside stability region: False
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#
#
#
#
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# Iteration # 49
# Current State Variable Values: x = [-4.54370367e-04  5.22554753e-10 -4.54370889e-04  4.54369844e-04
#   7.79346545e+00 -4.47507379e-04  5.10031072e-10 -4.47507889e-04
#   4.47506869e-04  8.18035112e+00]
# Current V Value:  48.64445820843848
# Outside economic region: False
# Outside stability region: False
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#
#
#
#
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# Iteration # 50
# Current State Variable Values: x = [-4.75823586e-04  5.48005023e-10 -4.75824134e-04  4.75823038e-04
#   7.95427283e+00 -4.68741459e-04  5.35035960e-10 -4.68741994e-04
#   4.68740924e-04  8.34875471e+00]
# Current V Value:  50.669410040554155
# Outside economic region: False
# Outside stability region: False
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#
#
#
#
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# Iteration # 51
# Current State Variable Values: x = [-4.97878353e-04  5.74226272e-10 -4.97878927e-04  4.97877779e-04
#   8.11502522e+00 -4.90577890e-04  5.60809816e-10 -4.90578451e-04
#   4.90577330e-04  8.51708557e+00]
# Current V Value:  52.734814866700376
# Outside economic region: False
# Outside stability region: False
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#
#
#
#
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# Iteration # 52
# Current State Variable Values: x = [-5.20542469e-04  6.01231505e-10 -5.20543071e-04  5.20541868e-04
#   8.27572321e+00 -5.13024777e-04  5.87366145e-10 -5.13025365e-04
#   5.13024190e-04  8.68534435e+00]
# Current V Value:  54.84063123769814
# Outside economic region: False
# Outside stability region: False
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#
#
#
#
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# Iteration # 53
# Current State Variable Values: x = [-5.43823827e-04  6.29033951e-10 -5.43824456e-04  5.43823198e-04
#   8.43636738e+00 -5.36090325e-04  6.14718694e-10 -5.36090940e-04
#   5.36089711e-04  8.85353172e+00]
# Current V Value:  56.98681846237187
# Outside economic region: False
# Outside stability region: False
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#
#
#
#
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# Iteration # 54
# Current State Variable Values: x = [-5.67730415e-04  6.57647071e-10 -5.67731073e-04  5.67729758e-04
#   8.59695833e+00 -5.59782841e-04  6.42881459e-10 -5.59783484e-04
#   5.59782198e-04  9.02164837e+00]
# Current V Value:  59.17333661684164
# Outside economic region: False
# Outside stability region: False
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#
#
#
#
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# Iteration # 55
# Current State Variable Values: x = [-5.92270316e-04  6.87084561e-10 -5.92271003e-04  5.92269629e-04
#   8.75749667e+00 -5.84110733e-04  6.71868690e-10 -5.84111405e-04
#   5.84110061e-04  9.18969497e+00]
# Current V Value:  61.40014655395244
# Outside economic region: False
# Outside stability region: False
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#
#
#
#
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# Iteration # 56
# Current State Variable Values: x = [-6.17451709e-04  7.17360358e-10 -6.17452426e-04  6.17450992e-04
#   8.91798300e+00 -6.09082512e-04  7.01694896e-10 -6.09083213e-04
#   6.09081810e-04  9.35767222e+00]
# Current V Value:  63.667209912845124
# Outside economic region: False
# Outside stability region: False
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#
#
#
#
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# Iteration # 57
# Current State Variable Values: x = [-6.43282872e-04  7.48488643e-10 -6.43283620e-04  6.43282123e-04
#   9.07841793e+00 -6.34706793e-04  7.32374849e-10 -6.34707525e-04
#   6.34706061e-04  9.52558082e+00]
# Current V Value:  65.9744891286695
# Outside economic region: False
# Outside stability region: False
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#
#
#
#
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# Iteration # 58
# Current State Variable Values: x = [-6.69772179e-04  7.80483847e-10 -6.69772960e-04  6.69771399e-04
#   9.23880210e+00 -6.60992299e-04  7.63923594e-10 -6.60993063e-04
#   6.60991535e-04  9.69342147e+00]
# Current V Value:  68.32194744244354
# Outside economic region: False
# Outside stability region: False
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#
#
#
#
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# Iteration # 59
# Current State Variable Values: x = [-6.96928108e-04  8.13360654e-10 -6.96928921e-04  6.96927294e-04
#   9.39913612e+00 -6.87947856e-04  7.96356446e-10 -6.87948652e-04
#   6.87947060e-04  9.86119489e+00]
# Current V Value:  70.70954891105976
# Outside economic region: False
# Outside stability region: False
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#
#
#
#
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# Iteration # 60
# Current State Variable Values: x = [-7.24759233e-04  8.47134008e-10 -7.24760080e-04  7.24758386e-04
#   9.55942065e+00 -7.15582401e-04  8.29689002e-10 -7.15583231e-04
#   7.15581571e-04  1.00289018e+01]
# Current V Value:  73.13725841744183
# Outside economic region: False
# Outside stability region: False
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#
#
#
#
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# Iteration # 61
# Current State Variable Values: x = [-7.53274233e-04  8.81819117e-10 -7.53275115e-04  7.53273351e-04
#   9.71965631e+00 -7.43904979e-04  8.63937147e-10 -7.43905843e-04
#   7.43904115e-04  1.01965429e+01]
# Current V Value:  75.60504168085477
# Outside economic region: False
# Outside stability region: False
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#
#
#
#
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# Iteration # 62
# Current State Variable Values: x = [-7.82481889e-04  9.17431458e-10 -7.82482806e-04  7.82480972e-04
#   9.87984375e+00 -7.72924745e-04  8.99117053e-10 -7.72925644e-04
#   7.72923846e-04  1.03641190e+01]
# Current V Value:  78.11286526736886
# Outside economic region: False
# Outside stability region: False
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#
#
#
#
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# Iteration # 63
# Current State Variable Values: x = [-8.12391087e-04  9.53986784e-10 -8.12392041e-04  8.12390133e-04
#   1.00399836e+01 -8.02650966e-04  9.35245195e-10 -8.02651901e-04
#   8.02650031e-04  1.05316307e+01]
# Current V Value:  80.66069660048248
# Outside economic region: False
# Outside stability region: False
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#
#
#
#
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# Iteration # 64
# Current State Variable Values: x = [-8.43010818e-04  9.91501126e-10 -8.43011809e-04  8.43009826e-04
#   1.02000766e+01 -8.33093023e-04  9.72338347e-10 -8.33093995e-04
#   8.33092050e-04  1.06990790e+01]
# Current V Value:  83.24850397190531
# Outside economic region: False
# Outside stability region: False
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#
#
#
#
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# Iteration # 65
# Current State Variable Values: x = [-8.74350179e-04  1.02999080e-09 -8.74351209e-04  8.74349149e-04
#   1.03601234e+01 -8.64260409e-04  1.01041360e-09 -8.64261419e-04
#   8.64259399e-04  1.08664644e+01]
# Current V Value:  85.87625655250396
# Outside economic region: False
# Outside stability region: False
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#
#
#
#
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# Iteration # 66
# Current State Variable Values: x = [-9.06418377e-04  1.06947242e-09 -9.06419447e-04  9.06417308e-04
#   1.05201247e+01 -8.96162735e-04  1.04948834e-09 -8.96163784e-04
#   8.96161685e-04  1.10337878e+01]
# Current V Value:  88.543924403415
# Outside economic region: False
# Outside stability region: False
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#
#
#
#
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# Iteration # 67
# Current State Variable Values: x = [-9.39224726e-04  1.10996288e-09 -9.39225836e-04  9.39223616e-04
#   1.06800810e+01 -9.28809728e-04  1.08958031e-09 -9.28810817e-04
#   9.28808638e-04  1.12010500e+01]
# Current V Value:  91.25147848732544
# Outside economic region: False
# Outside stability region: False
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#
#
#
#
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# Iteration # 68
# Current State Variable Values: x = [-9.72778650e-04  1.15147940e-09 -9.72779801e-04  9.72777498e-04
#   1.08399933e+01 -9.62211232e-04  1.13070755e-09 -9.62212363e-04
#   9.62210101e-04  1.13682517e+01]
# Current V Value:  93.9988906799256
# Outside economic region: False
# Outside stability region: False
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#
#
#
#
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# Iteration # 69
# Current State Variable Values: x = [-1.00708969e-03  1.19403949e-09 -1.00709088e-03  1.00708849e-03
#   1.09998620e+01 -9.96377213e-04  1.17288846e-09 -9.96378386e-04
#   9.96376040e-04  1.15353937e+01]
# Current V Value:  96.78613378153611
# Outside economic region: False
# Outside stability region: False
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#
#
#
#
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# Iteration # 70
# Current State Variable Values: x = [-1.04216748e-03  1.23766098e-09 -1.04216872e-03  1.04216625e-03
#   1.11596880e+01 -1.03131776e-03  1.21614176e-09 -1.03131897e-03
#   1.03131654e-03  1.17024769e+01]
# Current V Value:  99.61318152891361
# Outside economic region: False
# Outside stability region: False
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#
#
#
#
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# Iteration # 71
# Current State Variable Values: x = [-1.07802181e-03  1.28236203e-09 -1.07802309e-03  1.07802053e-03
#   1.13194720e+01 -1.06704307e-03  1.26048655e-09 -1.06704433e-03
#   1.06704181e-03  1.18695020e+01]
# Current V Value:  102.48000860723565
# Outside economic region: False
# Outside stability region: False
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#
#
#
#
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# Iteration # 72
# Current State Variable Values: x = [-1.11466253e-03  1.32816111e-09 -1.11466386e-03  1.11466121e-03
#   1.14792146e+01 -1.10356349e-03  1.30594225e-09 -1.10356479e-03
#   1.10356218e-03  1.20364699e+01]
# Current V Value:  105.38659066227075
# Outside economic region: False
# Outside stability region: False
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#
#
#
#
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# Iteration # 73
# Current State Variable Values: x = [-1.15209966e-03  1.37507704e-09 -1.15210104e-03  1.15209829e-03
#   1.16389167e+01 -1.14088947e-03  1.35252867e-09 -1.14089082e-03
#   1.14088811e-03  1.22033814e+01]
# Current V Value:  108.33290431273517
# Outside economic region: False
# Outside stability region: False
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#
#
#
#
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# Iteration # 74
# Current State Variable Values: x = [-1.19034330e-03  1.42312897e-09 -1.19034473e-03  1.19034188e-03
#   1.17985789e+01 -1.17903159e-03  1.40026599e-09 -1.17903299e-03
#   1.17903019e-03  1.23702373e+01]
# Current V Value:  111.3189271628394
# Outside economic region: False
# Outside stability region: False
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#
#
#
#
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# Iteration # 75
# Current State Variable Values: x = [-1.22940369e-03  1.47233642e-09 -1.22940516e-03  1.22940222e-03
#   1.19582020e+01 -1.21800057e-03  1.44917476e-09 -1.21800202e-03
#   1.21799912e-03  1.25370384e+01]
# Current V Value:  114.34463781502944
# Outside economic region: False
# Outside stability region: False
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#
#
#
#
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# Iteration # 76
# Current State Variable Values: x = [-1.26929118e-03  1.52271922e-09 -1.26929270e-03  1.26928965e-03
#   1.21177867e+01 -1.25780725e-03  1.49927593e-09 -1.25780874e-03
#   1.25780575e-03  1.27037858e+01]
# Current V Value:  117.41001588292427
# Outside economic region: False
# Outside stability region: False
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#
#
#
#
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# Iteration # 77
# Current State Variable Values: x = [-1.31001624e-03  1.57429762e-09 -1.31001781e-03  1.31001467e-03
#   1.22773339e+01 -1.29846260e-03  1.55059084e-09 -1.29846415e-03
#   1.29846105e-03  1.28704801e+01]
# Current V Value:  120.5150420044547
# Outside economic region: False
# Outside stability region: False
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#
#
#
#
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# Iteration # 78
# Current State Variable Values: x = [-1.35158948e-03  1.62709218e-09 -1.35159111e-03  1.35158785e-03
#   1.24368443e+01 -1.33997773e-03  1.60314123e-09 -1.33997933e-03
#   1.33997612e-03  1.30371222e+01]
# Current V Value:  123.65969785520568
# Outside economic region: False
# Outside stability region: False
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#
#
#
#
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# Iteration # 79
# Current State Variable Values: x = [-1.39402162e-03  1.68112389e-09 -1.39402330e-03  1.39401994e-03
#   1.25963186e+01 -1.38236387e-03  1.65694926e-09 -1.38236553e-03
#   1.38236222e-03  1.32037132e+01]
# Current V Value:  126.84396616196724
# Outside economic region: False
# Outside stability region: False
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#
#
#
#
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# Iteration # 80
# Current State Variable Values: x = [-1.43732351e-03  1.73641408e-09 -1.43732525e-03  1.43732178e-03
#   1.27557578e+01 -1.42563242e-03  1.71203751e-09 -1.42563413e-03
#   1.42563071e-03  1.33702537e+01]
# Current V Value:  130.06783071649676
# Outside economic region: False
# Outside stability region: False
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#
#
#
#
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# Iteration # 81
# Current State Variable Values: x = [-1.48150614e-03  1.79298450e-09 -1.48150793e-03  1.48150434e-03
#   1.29151624e+01 -1.46979487e-03  1.76842899e-09 -1.46979664e-03
#   1.46979310e-03  1.35367449e+01]
# Current V Value:  133.3312763894963
# Outside economic region: False
# Outside stability region: False
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#
#
#
#
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# Iteration # 82
# Current State Variable Values: x = [-1.52658060e-03  1.85085730e-09 -1.52658245e-03  1.52657875e-03
#   1.30745334e+01 -1.51486289e-03  1.82614715e-09 -1.51486471e-03
#   1.51486106e-03  1.37031874e+01]
# Current V Value:  136.6342891448096
# Outside economic region: False
# Outside stability region: False
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#
#
#
#
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# Iteration # 83
# Current State Variable Values: x = [-1.57255814e-03  1.91005503e-09 -1.57256005e-03  1.57255623e-03
#   1.32338716e+01 -1.56084826e-03  1.88521589e-09 -1.56085014e-03
#   1.56084637e-03  1.38695824e+01]
# Current V Value:  139.97685605384223
# Outside economic region: False
# Outside stability region: False
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#
#
#
#
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# Iteration # 84
# Current State Variable Values: x = [-1.61945013e-03  1.97060065e-09 -1.61945210e-03  1.61944816e-03
#   1.33931778e+01 -1.60776292e-03  1.94565956e-09 -1.60776486e-03
#   1.60776097e-03  1.40359307e+01]
# Current V Value:  143.35896531020921
# Outside economic region: False
# Outside stability region: False
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#
#
#
#
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# Iteration # 85
# Current State Variable Values: x = [-1.66726808e-03  2.03251756e-09 -1.66727011e-03  1.66726605e-03
#   1.35524529e+01 -1.65561895e-03  2.00750300e-09 -1.65562096e-03
#   1.65561695e-03  1.42022332e+01]
# Current V Value:  146.78060624461477
# Outside economic region: False
# Outside stability region: False
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#
#
#
#
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# Iteration # 86
# Current State Variable Values: x = [-1.71602362e-03  2.09582959e-09 -1.71602572e-03  1.71602152e-03
#   1.37116976e+01 -1.70442859e-03  2.07077151e-09 -1.70443066e-03
#   1.70442652e-03  1.43684909e+01]
# Current V Value:  150.2417693399663
# Outside economic region: False
# Outside stability region: False
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#
#
#
#
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# Iteration # 87
# Current State Variable Values: x = [-1.76572854e-03  2.16056102e-09 -1.76573070e-03  1.76572638e-03
#   1.38709129e+01 -1.75420419e-03  2.13549089e-09 -1.75420633e-03
#   1.75420206e-03  1.45347048e+01]
# Current V Value:  153.74244624673065
# Outside economic region: False
# Outside stability region: False
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#
#
#
#
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# Iteration # 88
# Current State Variable Values: x = [-1.81639475e-03  2.22673656e-09 -1.81639697e-03  1.81639252e-03
#   1.40300995e+01 -1.80495829e-03  2.20168743e-09 -1.80496049e-03
#   1.80495609e-03  1.47008759e+01]
# Current V Value:  157.28262979853292
# Outside economic region: False
# Outside stability region: False
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#
#
#
#
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# Iteration # 89
# Current State Variable Values: x = [-1.86803430e-03  2.29438141e-09 -1.86803660e-03  1.86803201e-03
#   1.41892584e+01 -1.85670356e-03  2.26938793e-09 -1.85670583e-03
#   1.85670129e-03  1.48670050e+01]
# Current V Value:  160.86231402800595
# Outside economic region: False
# Outside stability region: False
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#
#
#
#
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# Iteration # 90
# Current State Variable Values: x = [-1.92065940e-03  2.36352123e-09 -1.92066177e-03  1.92065704e-03
#   1.43483904e+01 -1.90945283e-03  2.33861973e-09 -1.90945516e-03
#   1.90945049e-03  1.50330933e+01]
# Current V Value:  164.48149418289358
# Outside economic region: False
# Outside stability region: False
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#
#
#
#
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# Iteration # 91
# Current State Variable Values: x = [-1.97428239e-03  2.43418216e-09 -1.97428483e-03  1.97427996e-03
#   1.45074965e+01 -1.96321907e-03  2.40941068e-09 -1.96322148e-03
#   1.96321666e-03  1.51991418e+01]
# Current V Value:  168.1401667424109
# Outside economic region: False
# Outside stability region: False
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#
#
#
#
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# Iteration # 92
# Current State Variable Values: x = [-2.02891576e-03  2.50639083e-09 -2.02891827e-03  2.02891326e-03
#   1.46665774e+01 -2.01801542e-03  2.48178919e-09 -2.01801790e-03
#   2.01801294e-03  1.53651513e+01]
# Current V Value:  171.8383294338709
# Outside economic region: False
# Outside stability region: False
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#
#
#
#
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# Iteration # 93
# Current State Variable Values: x = [-2.08457214e-03  2.58017438e-09 -2.08457472e-03  2.08456956e-03
#   1.48256342e+01 -2.07385519e-03  2.55578422e-09 -2.07385774e-03
#   2.07385263e-03  1.55311231e+01]
# Current V Value:  175.57598124957616
# Outside economic region: False
# Outside stability region: False
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#
#
#
#
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# Iteration # 94
# Current State Variable Values: x = [-2.14126431e-03  2.65556046e-09 -2.14126697e-03  2.14126166e-03
#   1.49846678e+01 -2.13075182e-03  2.63142530e-09 -2.13075445e-03
#   2.13074919e-03  1.56970580e+01]
# Current V Value:  179.35312246398732
# Outside economic region: False
# Outside stability region: False
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#
#
#
#
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# Iteration # 95
# Current State Variable Values: x = [-2.19900522e-03  2.73257725e-09 -2.19900795e-03  2.19900248e-03
#   1.51436790e+01 -2.18871894e-03  2.70874254e-09 -2.18872165e-03
#   2.18871624e-03  1.58629572e+01]
# Current V Value:  183.16975465116815
# Outside economic region: False
# Outside stability region: False
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#
#
#
#
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# Iteration # 96
# Current State Variable Values: x = [-2.25780793e-03  2.81125346e-09 -2.25781074e-03  2.25780512e-03
#   1.53026689e+01 -2.24777034e-03  2.78776666e-09 -2.24777312e-03
#   2.24776755e-03  1.60288217e+01]
# Current V Value:  187.02588070251554
# Outside economic region: False
# Outside stability region: False
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#
#
#
#
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# Iteration # 97
# Current State Variable Values: x = [-2.31768570e-03  2.89161834e-09 -2.31768859e-03  2.31768281e-03
#   1.54616383e+01 -2.30791995e-03  2.86852896e-09 -2.30792282e-03
#   2.30791708e-03  1.61946527e+01]
# Current V Value:  190.9215048447797
# Outside economic region: False
# Outside stability region: False
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#
#
#
#
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# Iteration # 98
# Current State Variable Values: x = [-2.37865192e-03  2.97370170e-09 -2.37865489e-03  2.37864895e-03
#   1.56205883e+01 -2.36918190e-03  2.95106138e-09 -2.36918485e-03
#   2.36917895e-03  1.63604511e+01]
# Current V Value:  194.85663265837837
# Outside economic region: False
# Outside stability region: False
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#
#
#
#
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# Iteration # 99
# Current State Variable Values: x = [-2.44072014e-03  3.05753393e-09 -2.44072320e-03  2.44071709e-03
#   1.57795198e+01 -2.43157047e-03  3.03539648e-09 -2.43157351e-03
#   2.43156744e-03  1.65262181e+01]
# Current V Value:  198.83127109601287
# Outside economic region: False
# Outside stability region: False
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#
#
#
#
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# Iteration # 100
# Current State Variable Values: x = [-2.50390408e-03  3.14314601e-09 -2.50390723e-03  2.50390094e-03
#   1.59384337e+01 -2.49510013e-03  3.12156750e-09 -2.49510325e-03
#   2.49509701e-03  1.66919547e+01]
# Current V Value:  202.84542850159045
# Outside economic region: False
# Outside stability region: False
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#
#
#
#
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# Iteration # 101
# Current State Variable Values: x = [-2.56821761e-03  3.23056948e-09 -2.56822084e-03  2.56821438e-03
#   1.60973311e+01 -2.55978551e-03  3.20960830e-09 -2.55978872e-03
#   2.55978230e-03  1.68576622e+01]
# Current V Value:  206.89911462945983
# Outside economic region: False
# Outside stability region: False
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#
#
#
#
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# Iteration # 102
# Current State Variable Values: x = [-2.63367477e-03  3.31983653e-09 -2.63367809e-03  2.63367145e-03
#   1.62562130e+01 -2.62564142e-03  3.29955345e-09 -2.62564472e-03
#   2.62563812e-03  1.70233416e+01]
# Current V Value:  210.99234066396508
# Outside economic region: False
# Outside stability region: False
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#
#
#
#
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# Iteration # 103
# Current State Variable Values: x = [-2.70028977e-03  3.41097993e-09 -2.70029318e-03  2.70028636e-03
#   1.64150804e+01 -2.69268286e-03  3.39143820e-09 -2.69268625e-03
#   2.69267947e-03  1.71889942e+01]
# Current V Value:  215.12511923932612
# Outside economic region: False
# Outside stability region: False
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#
#
#
#
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# Iteration # 104
# Current State Variable Values: x = [-2.76807696e-03  3.50403313e-09 -2.76808047e-03  2.76807346e-03
#   1.65739343e+01 -2.76092498e-03  3.48529851e-09 -2.76092847e-03
#   2.76092150e-03  1.73546209e+01]
# Current V Value:  219.29746445984796
# Outside economic region: False
# Outside stability region: False
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#
#
#
#
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# Iteration # 105
# Current State Variable Values: x = [-2.83705090e-03  3.59903019e-09 -2.83705450e-03  2.83704731e-03
#   1.67327757e+01 -2.83038316e-03  3.58117108e-09 -2.83038674e-03
#   2.83037958e-03  1.75202231e+01]
# Current V Value:  223.50939192047144
# Outside economic region: False
# Outside stability region: False
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#
#
#
#
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# Iteration # 106
# Current State Variable Values: x = [-2.90722630e-03  3.69600585e-09 -2.90723000e-03  2.90722261e-03
#   1.68916058e+01 -2.90107292e-03  3.67909332e-09 -2.90107660e-03
#   2.90106924e-03  1.76858019e+01]
# Current V Value:  227.76091872766685
# Outside economic region: False
# Outside stability region: False
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#
#
#
#
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# Iteration # 107
# Current State Variable Values: x = [-2.97861804e-03  3.79499553e-09 -2.97862184e-03  2.97861425e-03
#   1.70504255e+01 -2.97300999e-03  3.77910344e-09 -2.97301377e-03
#   2.97300621e-03  1.78513585e+01]
# Current V Value:  232.05206352068058
# Outside economic region: False
# Outside stability region: False
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#
#
#
#
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# Iteration # 108
# Current State Variable Values: x = [-3.05124118e-03  3.89603532e-09 -3.05124508e-03  3.05123729e-03
#   1.72092359e+01 -3.04621030e-03  3.88124038e-09 -3.04621418e-03
#   3.04620641e-03  1.80168942e+01]
# Current V Value:  236.38284649313923
# Outside economic region: False
# Outside stability region: False
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#
#
#
#
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# Iteration # 109
# Current State Variable Values: x = [-3.12511097e-03  3.99916205e-09 -3.12511496e-03  3.12510697e-03
#   1.73680382e+01 -3.12068994e-03  3.98554391e-09 -3.12069393e-03
#   3.12068596e-03  1.81824100e+01]
# Current V Value:  240.75328941502073
# Outside economic region: False
# Outside stability region: False
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#
#
#
#
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# Iteration # 110
# Current State Variable Values: x = [-3.20024281e-03  4.10441325e-09 -3.20024691e-03  3.20023870e-03
#   1.75268333e+01 -3.19646523e-03  4.09205460e-09 -3.19646933e-03
#   3.19646114e-03  1.83479074e+01]
# Current V Value:  245.1634156550005
# Outside economic region: False
# Outside stability region: False
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#
#
#
#
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# Iteration # 111
# Current State Variable Values: x = [-3.27665231e-03  4.21182718e-09 -3.27665652e-03  3.27664810e-03
#   1.76856225e+01 -3.27355267e-03  4.20081384e-09 -3.27355687e-03
#   3.27354847e-03  1.85133875e+01]
# Current V Value:  249.6132502031753
# Outside economic region: False
# Outside stability region: False
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#
#
#
#
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# Iteration # 112
# Current State Variable Values: x = [-3.35435526e-03  4.32144289e-09 -3.35435958e-03  3.35435094e-03
#   1.78444068e+01 -3.35196896e-03  4.31186387e-09 -3.35197327e-03
#   3.35196465e-03  1.86788516e+01]
# Current V Value:  254.10281969417886
# Outside economic region: False
# Outside stability region: False
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#
#
#
#
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# Iteration # 113
# Current State Variable Values: x = [-3.43336763e-03  4.43330016e-09 -3.43337206e-03  3.43336320e-03
#   1.80031874e+01 -3.43173100e-03  4.42524782e-09 -3.43173543e-03
#   3.43172658e-03  1.88443010e+01]
# Current V Value:  258.6321524306934
# Outside economic region: False
# Outside stability region: False
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#
#
#
#
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# Iteration # 114
# Current State Variable Values: x = [-3.51370558e-03  4.54743960e-09 -3.51371013e-03  3.51370103e-03
#   1.81619655e+01 -3.51285591e-03  4.54100968e-09 -3.51286045e-03
#   3.51285137e-03  1.90097370e+01]
# Current V Value:  263.201278407367
# Outside economic region: False
# Outside stability region: False
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#
#
#
#
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# Iteration # 115
# Current State Variable Values: x = [-3.59538546e-03  4.66390259e-09 -3.59539012e-03  3.59538079e-03
#   1.83207421e+01 -3.59536099e-03  4.65919437e-09 -3.59536565e-03
#   3.59535633e-03  1.91751609e+01]
# Current V Value:  267.81022933514095
# Outside economic region: False
# Outside stability region: False
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#
#
#
#
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# Iteration # 116
# Current State Variable Values: x = [-3.67842382e-03  4.78273135e-09 -3.67842860e-03  3.67841903e-03
#   1.84795184e+01 -3.67926378e-03  4.77984773e-09 -3.67926856e-03
#   3.67925900e-03  1.93405740e+01]
# Current V Value:  272.45903866600577
# Outside economic region: False
# Outside stability region: False
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#
#
#
#
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# Iteration # 117
# Current State Variable Values: x = [-3.76283739e-03  4.90396895e-09 -3.76284230e-03  3.76283249e-03
#   1.86382957e+01 -3.76458200e-03  4.90301655e-09 -3.76458691e-03
#   3.76457710e-03  1.95059776e+01]
# Current V Value:  277.14774161818025
# Outside economic region: False
# Outside stability region: False
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#
#
#
#
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# Iteration # 118
# Current State Variable Values: x = [-3.84864313e-03  5.02765930e-09 -3.84864816e-03  3.84863810e-03
#   1.87970751e+01 -3.85133363e-03  5.02874860e-09 -3.85133866e-03
#   3.85132860e-03  1.96713732e+01]
# Current V Value:  281.8763752017354
# Outside economic region: False
# Outside stability region: False
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#
#
#
#
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# Iteration # 119
# Current State Variable Values: x = [-3.93585817e-03  5.15384722e-09 -3.93586332e-03  3.93585302e-03
#   1.89558579e+01 -3.93953683e-03  5.15709264e-09 -3.93954198e-03
#   3.93953167e-03  1.98367621e+01]
# Current V Value:  286.6449782446658
# Outside economic region: False
# Outside stability region: False
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#
#
#
#
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# Iteration # 120
# Current State Variable Values: x = [-4.02449986e-03  5.28257840e-09 -4.02450514e-03  4.02449457e-03
#   1.91146452e+01 -4.02920998e-03  5.28809847e-09 -4.02921527e-03
#   4.02920470e-03  2.00021456e+01]
# Current V Value:  291.45359141941844
# Outside economic region: False
# Outside stability region: False
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#
#
#
#
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# Iteration # 121
# Current State Variable Values: x = [-4.11458574e-03  5.41389948e-09 -4.11459115e-03  4.11458033e-03
#   1.92734384e+01 -4.12037172e-03  5.42181690e-09 -4.12037714e-03
#   4.12036630e-03  2.01675252e+01]
# Current V Value:  296.30225726989056
# Outside economic region: False
# Outside stability region: False
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#
#
#
#
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# Iteration # 122
# Current State Variable Values: x = [-4.20613358e-03  5.54785802e-09 -4.20613913e-03  4.20612803e-03
#   1.94322386e+01 -4.21304088e-03  5.55829983e-09 -4.21304644e-03
#   4.21303532e-03  2.03329024e+01]
# Current V Value:  301.19102023890576
# Outside economic region: False
# Outside stability region: False
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#
#
#
#
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# Iteration # 123
# Current State Variable Values: x = [-4.29916135e-03  5.68450256e-09 -4.29916704e-03  4.29915567e-03
#   1.95910472e+01 -4.30723654e-03  5.69760025e-09 -4.30724224e-03
#   4.30723084e-03  2.04982784e+01]
# Current V Value:  306.1199266961768
# Outside economic region: False
# Outside stability region: False
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#
#
#
#
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# Iteration # 124
# Current State Variable Values: x = [-4.39368724e-03  5.82388260e-09 -4.39369306e-03  4.39368141e-03
#   1.97498653e+01 -4.40297800e-03  5.83977227e-09 -4.40298384e-03
#   4.40297216e-03  2.06636548e+01]
# Current V Value:  311.0890249667667
# Outside economic region: False
# Outside stability region: False
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#
#
#
#
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# Iteration # 125
# Current State Variable Values: x = [-4.48972964e-03  5.96604867e-09 -4.48973561e-03  4.48972367e-03
#   1.99086944e+01 -4.50028481e-03  5.98487114e-09 -4.50029079e-03
#   4.50027882e-03  2.08290331e+01]
# Current V Value:  316.0983653600642
# Outside economic region: False
# Outside stability region: False
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#
#
#
#
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# Iteration # 126
# Current State Variable Values: x = [-4.58730718e-03  6.11105234e-09 -4.58731329e-03  4.58730107e-03
#   2.00675357e+01 -4.59917674e-03  6.13295329e-09 -4.59918287e-03
#   4.59917061e-03  2.09944147e+01]
# Current V Value:  321.14800019926895
# Outside economic region: False
# Outside stability region: False
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#
#
#
#
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# Iteration # 127
# Current State Variable Values: x = [-4.68643870e-03  6.25894620e-09 -4.68644496e-03  4.68643244e-03
#   2.02263906e+01 -4.69967382e-03  6.28407634e-09 -4.69968010e-03
#   4.69966753e-03  2.11598012e+01]
# Current V Value:  326.2379838514193
# Outside economic region: False
# Outside stability region: False
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#
#
#
#
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# ...
# Iteration # 7159
# Current State Variable Values: x = [-9.13579199e-01  4.51099056e-05 -9.13624309e-01  9.13534089e-01
#   5.00440650e+01 -1.78366569e+00  2.95123472e-04 -1.78396081e+00
#   1.78337056e+00  1.01295461e+02]
# Current V Value:  12794.433425497187
# Outside economic region: False
# Outside stability region: False
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#
#
#
#
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# Iteration # 7160
# Current State Variable Values: x = [-9.13577579e-01  4.51099370e-05 -9.13622689e-01  9.13532469e-01
#   5.00440384e+01 -1.78366348e+00  2.95122110e-04 -1.78395861e+00
#   1.78336836e+00  1.01295205e+02]
# Current V Value:  12794.38700736226
# Outside economic region: False
# Outside stability region: False
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#
#
#
#
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# Iteration # 7161
# Current State Variable Values: x = [-9.13575959e-01  4.51099683e-05 -9.13621069e-01  9.13530849e-01
#   5.00440119e+01 -1.78366128e+00  2.95120747e-04 -1.78395640e+00
#   1.78336616e+00  1.01294949e+02]
# Current V Value:  12794.340601831123
# Outside economic region: False
# Outside stability region: False
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#
#
#
#
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# Iteration # 7162
# Current State Variable Values: x = [-9.13574341e-01  4.51099995e-05 -9.13619451e-01  9.13529231e-01
#   5.00439853e+01 -1.78365908e+00  2.95119385e-04 -1.78395420e+00
#   1.78336396e+00  1.01294693e+02]
# Current V Value:  12794.294208899413
# Outside economic region: False
# Outside stability region: False
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#
#
#
#
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# Iteration # 7163
# Current State Variable Values: x = [-9.13572724e-01  4.51100307e-05 -9.13617834e-01  9.13527614e-01
#   5.00439588e+01 -1.78365688e+00  2.95118024e-04 -1.78395199e+00
#   1.78336176e+00  1.01294437e+02]
# Current V Value:  12794.247828562744
# Outside economic region: False
# Outside stability region: False
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#
#
#
#
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# Iteration # 7164
# Current State Variable Values: x = [-9.13571107e-01  4.51100617e-05 -9.13616217e-01  9.13525997e-01
#   5.00439323e+01 -1.78365467e+00  2.95116662e-04 -1.78394979e+00
#   1.78335956e+00  1.01294181e+02]
# Current V Value:  12794.201460816766
# Outside economic region: False
# Outside stability region: False
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#
#
#
#
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# Iteration # 7165
# Current State Variable Values: x = [-9.13569492e-01  4.51100927e-05 -9.13614602e-01  9.13524382e-01
#   5.00439058e+01 -1.78365247e+00  2.95115300e-04 -1.78394759e+00
#   1.78335736e+00  1.01293926e+02]
# Current V Value:  12794.155105657079
# Outside economic region: False
# Outside stability region: False
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#
#
#
#
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# Iteration # 7166
# Current State Variable Values: x = [-9.13567877e-01  4.51101236e-05 -9.13612987e-01  9.13522767e-01
#   5.00438793e+01 -1.78365027e+00  2.95113939e-04 -1.78394539e+00
#   1.78335516e+00  1.01293670e+02]
# Current V Value:  12794.10876307931
# Outside economic region: False
# Outside stability region: False
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#
#
#
#
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# Iteration # 7167
# Current State Variable Values: x = [-9.13566263e-01  4.51101545e-05 -9.13611374e-01  9.13521153e-01
#   5.00438528e+01 -1.78364807e+00  2.95112577e-04 -1.78394318e+00
#   1.78335296e+00  1.01293414e+02]
# Current V Value:  12794.06243307911
# Outside economic region: False
# Outside stability region: False
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#
#
#
#
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# Iteration # 7168
# Current State Variable Values: x = [-9.13564651e-01  4.51101852e-05 -9.13609761e-01  9.13519541e-01
#   5.00438264e+01 -1.78364587e+00  2.95111216e-04 -1.78394098e+00
#   1.78335076e+00  1.01293159e+02]
# Current V Value:  12794.016115652099
# Outside economic region: False
# Outside stability region: False
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#
#
#
#
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# Iteration # 7169
# Current State Variable Values: x = [-9.13563039e-01  4.51102159e-05 -9.13608149e-01  9.13517929e-01
#   5.00438000e+01 -1.78364367e+00  2.95109855e-04 -1.78393878e+00
#   1.78334856e+00  1.01292903e+02]
# Current V Value:  12793.969810793915
# Outside economic region: False
# Outside stability region: False
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#
#
#
#
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# Iteration # 7170
# Current State Variable Values: x = [-9.13561428e-01  4.51102465e-05 -9.13606538e-01  9.13516318e-01
#   5.00437736e+01 -1.78364147e+00  2.95108493e-04 -1.78393658e+00
#   1.78334636e+00  1.01292648e+02]
# Current V Value:  12793.92351850019
# Outside economic region: False
# Outside stability region: False
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#
#
#
#
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# Iteration # 7171
# Current State Variable Values: x = [-9.13559818e-01  4.51102770e-05 -9.13604929e-01  9.13514708e-01
#   5.00437472e+01 -1.78363927e+00  2.95107132e-04 -1.78393438e+00
#   1.78334417e+00  1.01292392e+02]
# Current V Value:  12793.877238766572
# Outside economic region: False
# Outside stability region: False
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#
#
#
#
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# Iteration # 7172
# Current State Variable Values: x = [-9.13558209e-01  4.51103074e-05 -9.13603320e-01  9.13513099e-01
#   5.00437208e+01 -1.78363708e+00  2.95105771e-04 -1.78393218e+00
#   1.78334197e+00  1.01292137e+02]
# Current V Value:  12793.830971588673
# Outside economic region: False
# Outside stability region: False
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#
#
#
#
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# Iteration # 7173
# Current State Variable Values: x = [-9.13556601e-01  4.51103377e-05 -9.13601712e-01  9.13511491e-01
#   5.00436944e+01 -1.78363488e+00  2.95104410e-04 -1.78392998e+00
#   1.78333977e+00  1.01291882e+02]
# Current V Value:  12793.784716962164
# Outside economic region: False
# Outside stability region: False
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#
#
#
#
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# Iteration # 7174
# Current State Variable Values: x = [-9.13554994e-01  4.51103680e-05 -9.13600105e-01  9.13509884e-01
#   5.00436681e+01 -1.78363268e+00  2.95103050e-04 -1.78392778e+00
#   1.78333758e+00  1.01291626e+02]
# Current V Value:  12793.738474882675
# Outside economic region: False
# Outside stability region: False
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#
#
#
#
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# Iteration # 7175
# Current State Variable Values: x = [-9.13553388e-01  4.51103982e-05 -9.13598498e-01  9.13508278e-01
#   5.00436417e+01 -1.78363048e+00  2.95101689e-04 -1.78392559e+00
#   1.78333538e+00  1.01291371e+02]
# Current V Value:  12793.692245345856
# Outside economic region: False
# Outside stability region: False
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#
#
#
#
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# Iteration # 7176
# Current State Variable Values: x = [-9.13551783e-01  4.51104283e-05 -9.13596893e-01  9.13506672e-01
#   5.00436154e+01 -1.78362829e+00  2.95100329e-04 -1.78392339e+00
#   1.78333319e+00  1.01291116e+02]
# Current V Value:  12793.64602834735
# Outside economic region: False
# Outside stability region: False
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#
#
#
#
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# Iteration # 7177
# Current State Variable Values: x = [-9.13550179e-01  4.51104583e-05 -9.13595289e-01  9.13505068e-01
#   5.00435891e+01 -1.78362609e+00  2.95098968e-04 -1.78392119e+00
#   1.78333099e+00  1.01290861e+02]
# Current V Value:  12793.599823882796
# Outside economic region: False
# Outside stability region: False
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#
#
#
#
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# Iteration # 7178
# Current State Variable Values: x = [-9.13548575e-01  4.51104882e-05 -9.13593686e-01  9.13503465e-01
#   5.00435628e+01 -1.78362390e+00  2.95097608e-04 -1.78391899e+00
#   1.78332880e+00  1.01290606e+02]
# Current V Value:  12793.55363194786
# Outside economic region: False
# Outside stability region: False
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#
#
#
#
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# Iteration # 7179
# Current State Variable Values: x = [-9.13546973e-01  4.51105181e-05 -9.13592083e-01  9.13501862e-01
#   5.00435366e+01 -1.78362170e+00  2.95096248e-04 -1.78391680e+00
#   1.78332660e+00  1.01290351e+02]
# Current V Value:  12793.507452538175
# Outside economic region: False
# Outside stability region: False
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#
#
#
#
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# Iteration # 7180
# Current State Variable Values: x = [-9.13545371e-01  4.51105479e-05 -9.13590482e-01  9.13500261e-01
#   5.00435103e+01 -1.78361951e+00  2.95094887e-04 -1.78391460e+00
#   1.78332441e+00  1.01290096e+02]
# Current V Value:  12793.461285649417
# Outside economic region: False
# Outside stability region: False
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#
#
#
#
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# Iteration # 7181
# Current State Variable Values: x = [-9.13543771e-01  4.51105776e-05 -9.13588881e-01  9.13498660e-01
#   5.00434841e+01 -1.78361731e+00  2.95093527e-04 -1.78391241e+00
#   1.78332222e+00  1.01289841e+02]
# Current V Value:  12793.415131277234
# Outside economic region: False
# Outside stability region: False
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#
#
#
#
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# Iteration # 7182
# Current State Variable Values: x = [-9.13542171e-01  4.51106072e-05 -9.13587282e-01  9.13497061e-01
#   5.00434579e+01 -1.78361512e+00  2.95092167e-04 -1.78391021e+00
#   1.78332003e+00  1.01289586e+02]
# Current V Value:  12793.368989417264
# Outside economic region: False
# Outside stability region: False
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#
#
#
#
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# Iteration # 7183
# Current State Variable Values: x = [-9.13540572e-01  4.51106367e-05 -9.13585683e-01  9.13495462e-01
#   5.00434317e+01 -1.78361292e+00  2.95090808e-04 -1.78390802e+00
#   1.78331783e+00  1.01289331e+02]
# Current V Value:  12793.322860065182
# Outside economic region: False
# Outside stability region: False
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#
#
#
#
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# Iteration # 7184
# Current State Variable Values: x = [-9.13538975e-01  4.51106662e-05 -9.13584085e-01  9.13493864e-01
#   5.00434055e+01 -1.78361073e+00  2.95089448e-04 -1.78390582e+00
#   1.78331564e+00  1.01289076e+02]
# Current V Value:  12793.276743216647
# Outside economic region: False
# Outside stability region: False
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#
#
#
#
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# Iteration # 7185
# Current State Variable Values: x = [-9.13537378e-01  4.51106956e-05 -9.13582489e-01  9.13492267e-01
#   5.00433793e+01 -1.78360854e+00  2.95088088e-04 -1.78390363e+00
#   1.78331345e+00  1.01288822e+02]
# Current V Value:  12793.23063886732
# Outside economic region: False
# Outside stability region: False
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#
#
#
#
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# Iteration # 7186
# Current State Variable Values: x = [-9.13535782e-01  4.51107249e-05 -9.13580893e-01  9.13490671e-01
#   5.00433531e+01 -1.78360635e+00  2.95086729e-04 -1.78390143e+00
#   1.78331126e+00  1.01288567e+02]
# Current V Value:  12793.184547012861
# Outside economic region: False
# Outside stability region: False
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#
#
#
#
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# Iteration # 7187
# Current State Variable Values: x = [-9.13534187e-01  4.51107541e-05 -9.13579298e-01  9.13489076e-01
#   5.00433270e+01 -1.78360416e+00  2.95085369e-04 -1.78389924e+00
#   1.78330907e+00  1.01288312e+02]
# Current V Value:  12793.138467648942
# Outside economic region: False
# Outside stability region: False
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#
#
#
#
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# Iteration # 7188
# Current State Variable Values: x = [-9.13532593e-01  4.51107832e-05 -9.13577704e-01  9.13487482e-01
#   5.00433009e+01 -1.78360196e+00  2.95084010e-04 -1.78389705e+00
#   1.78330688e+00  1.01288058e+02]
# Current V Value:  12793.092400771238
# Outside economic region: False
# Outside stability region: False
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#
#
#
#
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# Iteration # 7189
# Current State Variable Values: x = [-9.13531000e-01  4.51108123e-05 -9.13576111e-01  9.13485889e-01
#   5.00432748e+01 -1.78359977e+00  2.95082651e-04 -1.78389486e+00
#   1.78330469e+00  1.01287803e+02]
# Current V Value:  12793.0463463754
# Outside economic region: False
# Outside stability region: False
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#
#
#
#
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# Iteration # 7190
# Current State Variable Values: x = [-9.13529408e-01  4.51108413e-05 -9.13574519e-01  9.13484297e-01
#   5.00432487e+01 -1.78359758e+00  2.95081292e-04 -1.78389266e+00
#   1.78330250e+00  1.01287549e+02]
# Current V Value:  12793.000304457108
# Outside economic region: False
# Outside stability region: False
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#
#
#
#
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# Iteration # 7191
# Current State Variable Values: x = [-9.13527816e-01  4.51108702e-05 -9.13572927e-01  9.13482706e-01
#   5.00432226e+01 -1.78359539e+00  2.95079933e-04 -1.78389047e+00
#   1.78330031e+00  1.01287294e+02]
# Current V Value:  12792.954275012027
# Outside economic region: False
# Outside stability region: False
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#
#
#
#
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# Iteration # 7192
# Current State Variable Values: x = [-9.13526226e-01  4.51108990e-05 -9.13571337e-01  9.13481115e-01
#   5.00431965e+01 -1.78359320e+00  2.95078574e-04 -1.78388828e+00
#   1.78329813e+00  1.01287040e+02]
# Current V Value:  12792.908258035835
# Outside economic region: False
# Outside stability region: False
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#
#
#
#
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# Iteration # 7193
# Current State Variable Values: x = [-9.13524637e-01  4.51109277e-05 -9.13569748e-01  9.13479526e-01
#   5.00431705e+01 -1.78359101e+00  2.95077215e-04 -1.78388609e+00
#   1.78329594e+00  1.01286786e+02]
# Current V Value:  12792.862253524198
# Outside economic region: False
# Outside stability region: False
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#
#
#
#
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# Iteration # 7194
# Current State Variable Values: x = [-9.13523048e-01  4.51109564e-05 -9.13568159e-01  9.13477937e-01
#   5.00431445e+01 -1.78358883e+00  2.95075856e-04 -1.78388390e+00
#   1.78329375e+00  1.01286531e+02]
# Current V Value:  12792.816261472803
# Outside economic region: False
# Outside stability region: False
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#
#
#
#
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# Iteration # 7195
# Current State Variable Values: x = [-9.13521461e-01  4.51109850e-05 -9.13566572e-01  9.13476350e-01
#   5.00431184e+01 -1.78358664e+00  2.95074498e-04 -1.78388171e+00
#   1.78329156e+00  1.01286277e+02]
# Current V Value:  12792.770281877332
# Outside economic region: False
# Outside stability region: False
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#
#
#
#
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# Iteration # 7196
# Current State Variable Values: x = [-9.13519874e-01  4.51110135e-05 -9.13564985e-01  9.13474763e-01
#   5.00430924e+01 -1.78358445e+00  2.95073139e-04 -1.78387952e+00
#   1.78328938e+00  1.01286023e+02]
# Current V Value:  12792.724314733472
# Outside economic region: False
# Outside stability region: False
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#
#
#
#
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# Iteration # 7197
# Current State Variable Values: x = [-9.13518288e-01  4.51110419e-05 -9.13563399e-01  9.13473177e-01
#   5.00430665e+01 -1.78358226e+00  2.95071781e-04 -1.78387733e+00
#   1.78328719e+00  1.01285769e+02]
# Current V Value:  12792.678360036885
# Outside economic region: False
# Outside stability region: False
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#
#
#
#
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# Iteration # 7198
# Current State Variable Values: x = [-9.13516704e-01  4.51110702e-05 -9.13561815e-01  9.13471593e-01
#   5.00430405e+01 -1.78358008e+00  2.95070422e-04 -1.78387515e+00
#   1.78328501e+00  1.01285515e+02]
# Current V Value:  12792.63241778328
# Outside economic region: False
# Outside stability region: False
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#
#
#
#
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# Iteration # 7199
# Current State Variable Values: x = [-9.13515120e-01  4.51110985e-05 -9.13560231e-01  9.13470009e-01
#   5.00430145e+01 -1.78357789e+00  2.95069064e-04 -1.78387296e+00
#   1.78328282e+00  1.01285261e+02]
# Current V Value:  12792.586487968325
# Outside economic region: False
# Outside stability region: False
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#
#
#
#
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# Iteration # 7200
# Current State Variable Values: x = [-9.13513537e-01  4.51111267e-05 -9.13558648e-01  9.13468426e-01
#   5.00429886e+01 -1.78357570e+00  2.95067706e-04 -1.78387077e+00
#   1.78328064e+00  1.01285007e+02]
# Current V Value:  12792.54057058772
# Outside economic region: False
# Outside stability region: False
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# Total time required to execute the code = 2614.655120 seconds

# %%
from controllers import *
# %matplotlib widget
plt.rcParams['font.size'] = 15
plt.rcParams['figure.constrained_layout.use'] = True
plt.rcParams['pdf.fonttype'] = 42  # Use TrueType fonts
plt.rcParams['ps.fonttype'] = 42   # Also for PostScript outputs
plt.rcParams['text.usetex'] = False
plt.gcf().align_ylabels()
plt.close('all')
fig = plt.figure(figsize = (10,15))
grid = fig.add_gridspec(7,2,hspace = 0)
axes = grid.subplots(sharex=True,sharey=False)

stateNames = np.array(['C_B_1_record', 'C_DEB_1_record', 'C_E_1_record', 'C_EB_1_record', 'T_1_record', 'C_B_2_record', 'C_DEB_2_record', 'C_E_2_record', 'C_EB_2_record', 'T_2_record']).reshape(2,5)
controlNames = ['Q_1_record', 'Q_2_record']
stateVariableNames = np.array(['C_B1d', 'C_DEB1d', 'C_E1d', 'C_EB1d', 'T_1d', 'C_B2d', 'C_DEB2d', 'C_E2d', 'C_EB2d', 'T_2d']).reshape(2,5)
controlVariableNames = ['Q1d', 'Q2d']
steadystateVariableNames = np.array(['C_B1s', 'C_DEB1s', 'C_E1s', 'C_EB1s', 'T_1s', 'C_B2s', 'C_DEB2s', 'C_E2s', 'C_EB2s', 'T_2s']).reshape(2,5)
steadycontrolVariableNames = ['Q1s', 'Q2s']

#Plotting the results
colors = ['r', 'k', 'b', 'y', 'g','m']
labels = ['C_{B', 'C_{DEB', 'C_{E', 'C_{EB', 'T','Q']

for i in range(6):
        for j in range(2):
            if i<4:
                latex_label = f"${labels[i]}_{{{j+1}}}}}$"
                latex_labels = f"${{{labels[i]}_{{{j+1}_{{s}}}}}}}}$"
            else:
                latex_label = f"${labels[i]}_{{{j+1}}}$"
                latex_labels = f"${{{labels[i]}_{{{j+1}_{{s}}}}}}$"
            if i==5:
                axes[i,j].plot(np.array(np.loadtxt(os.path.join('Results_PIcontrol-Unencrypted', f'{controlNames[j]}.txt'), delimiter = ",")[:np.loadtxt(os.path.join('Results_PIcontrol-Unencrypted', 'finalIteration.txt'), delimiter = ",",dtype=int)])+globals()[steadycontrolVariableNames[j]],colors[i],label=latex_label)
                axes[i,j].axhline(globals()[controlVariableNames[j]]+globals()[steadycontrolVariableNames[j]],color=colors[i],linestyle='--',label=latex_labels)
            else:    
                axes[i,j].plot(np.array(np.loadtxt(os.path.join('Results_PIcontrol-Unencrypted', f'{stateNames[j,i]}.txt'), delimiter = ",")[:np.loadtxt(os.path.join('Results_PIcontrol-Unencrypted', 'finalIteration.txt'), delimiter = ",",dtype=int)])+globals()[steadystateVariableNames[j,i]],colors[i],label=latex_label)
                axes[i,j].axhline(globals()[stateVariableNames[j,i]]+globals()[steadystateVariableNames[j,i]],color=colors[i],linestyle='--',label=latex_labels)
            axes[i,j].set_xlabel('Time [s]')
            axes[i,j].set_ylabel(latex_label)
            axes[i,j].legend()
for ax in axes[-1,:]:
    ax.remove()
cost_axis = fig.add_subplot(grid[-1, :])  # Span across both columns
cost_axis.plot(np.loadtxt(os.path.join('Results_PIcontrol-Unencrypted', 'costRecord.txt'), delimiter = ","), 'c', label='Cost')
cost_axis.set_xlabel('Time [s]')
cost_axis.set_ylabel('Cost')
# Adjust tick marks for cost_axis only
cost_axis.locator_params(axis='x', nbins=5)  # Fewer ticks on x-axis
cost_axis.locator_params(axis='y', nbins=5)  # Fewer ticks on y-axis
cost_axis.legend()
# Adjust the layout so plots do not overlap
#plt.tight_layout()
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
